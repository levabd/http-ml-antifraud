# %%
import pandas as pd
import numpy as np

import scipy.sparse
import sklearn.feature_extraction

import matplotlib.pylab as plt
# %matplotlib inline

from tqdm import tqdm
import platform

pd.set_option("display.max_rows", 10)
pd.set_option('display.max_columns', 1100)

import os

# %pylab inline
warnings.filterwarnings('ignore')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### В матрице Main table всего 3 столбца, которые глобально характеризуют хэдэр

# %%
from logParser import ParseLogsFromFolder

main_data, values_data, order_data = ParseLogsFromFolder('Logs/', 0, 10, only_order=False)

main = pd.DataFrame(main_data)
#del(main_data)
print('Shape: ' + str(main.shape))
main.head()
# Out:
#   6%|▌         | 7/127 [00:04<01:14,  1.62it/s]
# Shape: (289269, 3)
#                                           User_Agent          id  \
# 0  Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.3...  1485900038
# 1  Mozilla/5.0 (compatible; bingbot/2.0; +http://...  1485900047
# 2  Mozilla/5.0 (Linux; Android 4.4.2; Zera S Buil...  1485900079
# 3  Mozilla/5.0 (Windows NT 6.1; WOW64; rv:51.0) G...  1485900103
# 4  Mozilla/4.0 (compatible; MSIE 8.0; Windows NT ...  1485900105
#
#                ip
# 0   95.181.252.91
# 1    40.77.167.74
# 2     31.148.3.19
# 3  188.162.183.66
# 4   37.144.52.103

# %%
print('Хэдэры первых 100 юзер-агентов составляют: {:.2%}'.format(
    main.User_Agent.value_counts()[:100].sum() / main.shape[0]))

print('Сохраним индексы хэдэров из топ-100')
main_top_100 = main[main.User_Agent.isin(main.User_Agent.value_counts()[:100].index)]
#del(main)

top_ua = main.User_Agent.value_counts()[:100].index.tolist()
# Out:
# Хэдэры первых 100 юзер-агентов составляют: 62.87%
# Сохраним индексы хэдэров из топ-100

# %%
print('В order_data содержится информация о взаимном расположении ключей.')
print('Переведем ее к типу csr с помощью DictVectorizer')
orders_vectorizer = sklearn.feature_extraction.DictVectorizer(sparse=True, dtype=float)
sparse_orders = orders_vectorizer.fit_transform(order_data).astype(np.int8)
#del(order_data)
# Out:
# В order_data содержится информация о взаимном расположении ключей.
# Переведем ее к типу csr с помощью DictVectorizer

# %%
sparse_orders.getrow(0)
# Out:
# <1x174 sparse matrix of type '<class 'numpy.int8'>'
# 	with 6 stored elements in Compressed Sparse Row format>

# %% [markdown]
# Можно было бы сразу создать нужную нам спарс матрицу с признаками попарным сравнением порядков. Однако в этом случае придется думать, как бы запомнить какой признак, что значит.
#
# Так что я решил не думать и сделать по аналогии с вышеприведенным преобразованием: с созданием соответствующего списка словарей и DictVectorizer-a

# %%
from itertools import combinations

sparse_orders_top_100 = sparse_orders[main_top_100.index]

pairs_dict_list = []
for row_index in tqdm(range(sparse_orders_top_100.shape[0]), mininterval=2):
    pairs_dict = {}
    for pair_first, pair_second in combinations(sparse_orders_top_100[row_index].indices, 2):
        name_first = orders_vectorizer.feature_names_[pair_first]
        name_second = orders_vectorizer.feature_names_[pair_second]
        if sparse_orders_top_100[row_index, pair_first] < sparse_orders_top_100[row_index, pair_second]:
            pairs_dict['{0} < {1}'.format(name_first, name_second)] = 1
        else:
            pairs_dict['{0} < {1}'.format(name_second, name_first)] = 1
    pairs_dict_list.append(pairs_dict)
# Out:
# 100%|██████████| 181851/181851 [02:58<00:00, 1020.24it/s]

# %%
sparse_orders_top_100.shape
# Out:
# (181851, 174)

# %%
main_top_100.shape
# Out:
# (181851, 3)

# %%
pairs_dict_list
# Out:
# [{'Accept < Accept-Encoding': 1,
#   'Accept < Accept-Language': 1,
#   'Accept < Referer': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Referer < Accept-Encoding': 1,
#   'Referer < Accept-Language': 1,
#   'Upgrade-Insecure-Requests < Accept': 1,
#   'Upgrade-Insecure-Requests < Accept-Encoding': 1,
#   'Upgrade-Insecure-Requests < Accept-Language': 1,
#   'Upgrade-Insecure-Requests < Referer': 1,
#   'Upgrade-Insecure-Requests < User-Agent': 1,
#   'User-Agent < Accept': 1,
#   'User-Agent < Accept-Encoding': 1,
#   'User-Agent < Accept-Language': 1,
#   'User-Agent < Referer': 1},
#  {'Accept < Accept-Encoding': 1,
#   'Accept < From': 1,
#   'Accept < Host': 1,
#   'Accept < User-Agent': 1,
#   'Accept-Encoding < From': 1,
#   'Accept-Encoding < Host': 1,
#   'Accept-Encoding < User-Agent': 1,
#   'From < Host': 1,
#   'From < User-Agent': 1,
#   'Host < User-Agent': 1,
#   'Pragma < Accept': 1,
#   'Pragma < Accept-Encoding': 1,
#   'Pragma < From': 1,
#   'Pragma < Host': 1,
#   'Pragma < User-Agent': 1},
#  {'Accept < Accept-Encoding': 1,
#   'Accept < Accept-Language': 1,
#   'Accept < Connection': 1,
#   'Accept < Cookie': 1,
#   'Accept < Referer': 1,
#   'Accept < Upgrade-Insecure-Requests': 1,
#   'Accept-Encoding < Connection': 1,
#   'Accept-Encoding < Cookie': 1,
#   'Accept-Encoding < Referer': 1,
#   'Accept-Encoding < Upgrade-Insecure-Requests': 1,
#   'Accept-Language < Accept-Encoding': 1,
#   'Accept-Language < Connection': 1,
#   'Accept-Language < Cookie': 1,
#   'Accept-Language < Referer': 1,
#   'Accept-Language < Upgrade-Insecure-Requests': 1,
#   'Connection < Upgrade-Insecure-Requests': 1,
#   'Cookie < Connection': 1,
#   'Cookie < Upgrade-Insecure-Requests': 1,
#   'Referer < Connection': 1,
#   'Referer < Cookie': 1,
#   'Referer < Upgrade-Insecure-Requests': 1},
#  {'Accept < Accept-Charset': 1,
#   'Accept-Encoding < Accept': 1,
#   'Accept-Encoding < Accept-Charset': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Accept-Language < Accept': 1,
#   'Accept-Language < Accept-Charset': 1},
#  {'Accept < Accept-Charset': 1,
#   'Accept-Encoding < Accept': 1,
#   'Accept-Encoding < Accept-Charset': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Accept-Language < Accept': 1,
#   'Accept-Language < Accept-Charset': 1},
#  {'Accept-Encoding < Connection': 1,
#   'Accept-Encoding < User-Agent': 1,
#   'Accept-Language < Accept-Encoding': 1,
#   'Accept-Language < Connection': 1,
#   'Accept-Language < User-Agent': 1,
#   'Connection < User-Agent': 1},
#  {'Accept < Accept-Charset': 1,
#   'Accept-Encoding < Accept': 1,
#   'Accept-Encoding < Accept-Charset': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Accept-Language < Accept': 1,
#   'Accept-Language < Accept-Charset': 1},
#  {'Accept < Host': 1},
#  {'Accept < Cookie': 1, 'Accept < Host': 1, 'Host < Cookie': 1},
#  {'Accept < Cookie': 1, 'Accept < Host': 1, 'Host < Cookie': 1},
#  {'Accept < Cookie': 1, 'Accept < Host': 1, 'Host < Cookie': 1},
#  {'Accept < Cookie': 1, 'Accept < Host': 1, 'Host < Cookie': 1},
#  {'Accept < Cookie': 1, 'Accept < Host': 1, 'Host < Cookie': 1},
#  {'Accept < Cookie': 1, 'Accept < Host': 1, 'Host < Cookie': 1},
#  {'Accept < Cookie': 1, 'Accept < Host': 1, 'Host < Cookie': 1},
#  {'Accept < Cookie': 1, 'Accept < Host': 1, 'Host < Cookie': 1},
#  {'Accept < Cookie': 1, 'Accept < Host': 1, 'Host < Cookie': 1},
#  {'Accept < Cookie': 1, 'Accept < Host': 1, 'Host < Cookie': 1},
#  {'Accept < Cookie': 1, 'Accept < Host': 1, 'Host < Cookie': 1},
#  {'Accept < Cookie': 1, 'Accept < Host': 1, 'Host < Cookie': 1},
#  {'Accept < Cookie': 1, 'Accept < Host': 1, 'Host < Cookie': 1},
#  {'Accept < Cookie': 1, 'Accept < Host': 1, 'Host < Cookie': 1},
#  {'Accept < Content-Length': 1,
#   'Accept < Content-Type': 1,
#   'Accept < Cookie': 1,
#   'Accept < Host': 1,
#   'Accept < Referer': 1,
#   'Content-Length < Content-Type': 1,
#   'Content-Length < Cookie': 1,
#   'Content-Type < Cookie': 1,
#   'Host < Content-Length': 1,
#   'Host < Content-Type': 1,
#   'Host < Cookie': 1,
#   'Host < Referer': 1,
#   'Referer < Content-Length': 1,
#   'Referer < Content-Type': 1,
#   'Referer < Cookie': 1},
#  {'Accept < Host': 1},
#  {'Accept < Cookie': 1, 'Accept < Host': 1, 'Host < Cookie': 1},
#  {'Accept < Cookie': 1, 'Accept < Host': 1, 'Host < Cookie': 1},
#  {'Accept-Encoding < Connection': 1,
#   'Accept-Encoding < User-Agent': 1,
#   'Accept-Language < Accept-Encoding': 1,
#   'Accept-Language < Connection': 1,
#   'Accept-Language < User-Agent': 1,
#   'Connection < User-Agent': 1},
#  {'Accept < Accept-Charset': 1,
#   'Accept-Encoding < Accept': 1,
#   'Accept-Encoding < Accept-Charset': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Accept-Language < Accept': 1,
#   'Accept-Language < Accept-Charset': 1},
#  {'Accept < Accept-Encoding': 1,
#   'Accept < User-Agent': 1,
#   'User-Agent < Accept-Encoding': 1},
#  {'Accept-Encoding < Accept': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Accept-Language < Accept': 1,
#   'From < Accept': 1,
#   'From < Accept-Encoding': 1,
#   'From < Accept-Language': 1,
#   'User-Agent < Accept': 1,
#   'User-Agent < Accept-Encoding': 1,
#   'User-Agent < Accept-Language': 1,
#   'User-Agent < From': 1},
#  {'Accept < Accept-Charset': 1,
#   'Accept-Encoding < Accept': 1,
#   'Accept-Encoding < Accept-Charset': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Accept-Language < Accept': 1,
#   'Accept-Language < Accept-Charset': 1},
#  {'Accept < Accept-Encoding': 1,
#   'Accept < From': 1,
#   'Accept < User-Agent': 1,
#   'From < Accept-Encoding': 1,
#   'From < User-Agent': 1,
#   'User-Agent < Accept-Encoding': 1},
#  {'Accept < Accept-Charset': 1,
#   'Accept-Encoding < Accept': 1,
#   'Accept-Encoding < Accept-Charset': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Accept-Language < Accept': 1,
#   'Accept-Language < Accept-Charset': 1},
#  {'Accept < Accept-Charset': 1,
#   'Accept-Encoding < Accept': 1,
#   'Accept-Encoding < Accept-Charset': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Accept-Language < Accept': 1,
#   'Accept-Language < Accept-Charset': 1},
#  {'Accept < Accept-Encoding': 1,
#   'Accept < Accept-Language': 1,
#   'Accept < Referer': 1,
#   'Accept < User-Agent': 1,
#   'Accept-Language < Accept-Encoding': 1,
#   'Referer < Accept-Encoding': 1,
#   'Referer < Accept-Language': 1,
#   'Upgrade-Insecure-Requests < Accept': 1,
#   'Upgrade-Insecure-Requests < Accept-Encoding': 1,
#   'Upgrade-Insecure-Requests < Accept-Language': 1,
#   'Upgrade-Insecure-Requests < Referer': 1,
#   'Upgrade-Insecure-Requests < User-Agent': 1,
#   'User-Agent < Accept-Encoding': 1,
#   'User-Agent < Accept-Language': 1,
#   'User-Agent < Referer': 1},
#  {'Accept < Accept-Charset': 1,
#   'Accept-Encoding < Accept': 1,
#   'Accept-Encoding < Accept-Charset': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Accept-Language < Accept': 1,
#   'Accept-Language < Accept-Charset': 1},
#  {'Accept-Encoding < Connection': 1,
#   'Accept-Encoding < User-Agent': 1,
#   'Accept-Language < Accept-Encoding': 1,
#   'Accept-Language < Connection': 1,
#   'Accept-Language < User-Agent': 1,
#   'Connection < User-Agent': 1},
#  {'Accept < Accept-Encoding': 1,
#   'Accept < Accept-Language': 1,
#   'Accept < Referer': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Referer < Accept-Encoding': 1,
#   'Referer < Accept-Language': 1,
#   'Upgrade-Insecure-Requests < Accept': 1,
#   'Upgrade-Insecure-Requests < Accept-Encoding': 1,
#   'Upgrade-Insecure-Requests < Accept-Language': 1,
#   'Upgrade-Insecure-Requests < Referer': 1,
#   'Upgrade-Insecure-Requests < User-Agent': 1,
#   'User-Agent < Accept': 1,
#   'User-Agent < Accept-Encoding': 1,
#   'User-Agent < Accept-Language': 1,
#   'User-Agent < Referer': 1},
#  {'Accept < Accept-Charset': 1,
#   'Accept-Encoding < Accept': 1,
#   'Accept-Encoding < Accept-Charset': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Accept-Language < Accept': 1,
#   'Accept-Language < Accept-Charset': 1},
#  {'Accept < Accept-Encoding': 1,
#   'Accept < Accept-Language': 1,
#   'Accept < Connection': 1,
#   'Accept < Referer': 1,
#   'Accept < Upgrade-Insecure-Requests': 1,
#   'Accept-Encoding < Connection': 1,
#   'Accept-Encoding < Referer': 1,
#   'Accept-Encoding < Upgrade-Insecure-Requests': 1,
#   'Accept-Language < Accept-Encoding': 1,
#   'Accept-Language < Connection': 1,
#   'Accept-Language < Referer': 1,
#   'Accept-Language < Upgrade-Insecure-Requests': 1,
#   'Connection < Upgrade-Insecure-Requests': 1,
#   'Referer < Connection': 1,
#   'Referer < Upgrade-Insecure-Requests': 1},
#  {'Accept < Accept-Charset': 1,
#   'Accept-Encoding < Accept': 1,
#   'Accept-Encoding < Accept-Charset': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Accept-Language < Accept': 1,
#   'Accept-Language < Accept-Charset': 1},
#  {'Accept < Accept-Charset': 1,
#   'Accept-Encoding < Accept': 1,
#   'Accept-Encoding < Accept-Charset': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Accept-Language < Accept': 1,
#   'Accept-Language < Accept-Charset': 1},
#  {'User-Agent < Accept-Encoding': 1},
#  {'Accept < Accept-Encoding': 1,
#   'Accept < From': 1,
#   'Accept < Host': 1,
#   'Accept < User-Agent': 1,
#   'Accept-Encoding < From': 1,
#   'Accept-Encoding < Host': 1,
#   'Accept-Encoding < User-Agent': 1,
#   'From < Host': 1,
#   'From < User-Agent': 1,
#   'Host < User-Agent': 1,
#   'Pragma < Accept': 1,
#   'Pragma < Accept-Encoding': 1,
#   'Pragma < From': 1,
#   'Pragma < Host': 1,
#   'Pragma < User-Agent': 1},
#  {'Host < Referer': 1, 'Host < User-Agent': 1, 'Referer < User-Agent': 1},
#  {'Accept < Accept-Charset': 1,
#   'Accept-Encoding < Accept': 1,
#   'Accept-Encoding < Accept-Charset': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Accept-Language < Accept': 1,
#   'Accept-Language < Accept-Charset': 1},
#  {'Accept < Accept-Charset': 1,
#   'Accept-Encoding < Accept': 1,
#   'Accept-Encoding < Accept-Charset': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Accept-Language < Accept': 1,
#   'Accept-Language < Accept-Charset': 1},
#  {'Accept < Accept-Encoding': 1,
#   'Accept < Accept-Language': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Cache-Control < Accept': 1,
#   'Cache-Control < Accept-Encoding': 1,
#   'Cache-Control < Accept-Language': 1,
#   'Cache-Control < Upgrade-Insecure-Requests': 1,
#   'Cache-Control < User-Agent': 1,
#   'Upgrade-Insecure-Requests < Accept': 1,
#   'Upgrade-Insecure-Requests < Accept-Encoding': 1,
#   'Upgrade-Insecure-Requests < Accept-Language': 1,
#   'Upgrade-Insecure-Requests < User-Agent': 1,
#   'User-Agent < Accept': 1,
#   'User-Agent < Accept-Encoding': 1,
#   'User-Agent < Accept-Language': 1},
#  {'Host < Connection': 1,
#   'User-Agent < Connection': 1,
#   'User-Agent < Host': 1},
#  {'Accept < Accept-Encoding': 1,
#   'Accept < Accept-Language': 1,
#   'Accept < Referer': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Referer < Accept-Encoding': 1,
#   'Referer < Accept-Language': 1,
#   'Upgrade-Insecure-Requests < Accept': 1,
#   'Upgrade-Insecure-Requests < Accept-Encoding': 1,
#   'Upgrade-Insecure-Requests < Accept-Language': 1,
#   'Upgrade-Insecure-Requests < Referer': 1,
#   'Upgrade-Insecure-Requests < User-Agent': 1,
#   'User-Agent < Accept': 1,
#   'User-Agent < Accept-Encoding': 1,
#   'User-Agent < Accept-Language': 1,
#   'User-Agent < Referer': 1},
#  {'Accept-Encoding < Host': 1,
#   'Accept-Language < Accept-Encoding': 1,
#   'Accept-Language < Connection': 1,
#   'Accept-Language < Host': 1,
#   'Connection < Accept-Encoding': 1,
#   'Connection < Host': 1,
#   'User-Agent < Accept-Encoding': 1,
#   'User-Agent < Accept-Language': 1,
#   'User-Agent < Connection': 1,
#   'User-Agent < Host': 1},
#  {'Accept < Accept-Encoding': 1,
#   'Accept < Accept-Language': 1,
#   'Accept < Referer': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Referer < Accept-Encoding': 1,
#   'Referer < Accept-Language': 1,
#   'Upgrade-Insecure-Requests < Accept': 1,
#   'Upgrade-Insecure-Requests < Accept-Encoding': 1,
#   'Upgrade-Insecure-Requests < Accept-Language': 1,
#   'Upgrade-Insecure-Requests < Referer': 1,
#   'Upgrade-Insecure-Requests < User-Agent': 1,
#   'User-Agent < Accept': 1,
#   'User-Agent < Accept-Encoding': 1,
#   'User-Agent < Accept-Language': 1,
#   'User-Agent < Referer': 1},
#  {'Accept < Accept-Encoding': 1,
#   'Accept < Accept-Language': 1,
#   'Accept < Referer': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Referer < Accept-Encoding': 1,
#   'Referer < Accept-Language': 1,
#   'Upgrade-Insecure-Requests < Accept': 1,
#   'Upgrade-Insecure-Requests < Accept-Encoding': 1,
#   'Upgrade-Insecure-Requests < Accept-Language': 1,
#   'Upgrade-Insecure-Requests < Referer': 1,
#   'Upgrade-Insecure-Requests < User-Agent': 1,
#   'User-Agent < Accept': 1,
#   'User-Agent < Accept-Encoding': 1,
#   'User-Agent < Accept-Language': 1,
#   'User-Agent < Referer': 1},
#  {'Accept < Accept-Encoding': 1,
#   'Accept < From': 1,
#   'Accept < Host': 1,
#   'Accept < User-Agent': 1,
#   'Accept-Encoding < From': 1,
#   'Accept-Encoding < Host': 1,
#   'Accept-Encoding < User-Agent': 1,
#   'From < Host': 1,
#   'From < User-Agent': 1,
#   'Host < User-Agent': 1,
#   'Pragma < Accept': 1,
#   'Pragma < Accept-Encoding': 1,
#   'Pragma < From': 1,
#   'Pragma < Host': 1,
#   'Pragma < User-Agent': 1},
#  {'Accept < Accept-Encoding': 1,
#   'Accept < From': 1,
#   'Accept < Host': 1,
#   'Accept < User-Agent': 1,
#   'Accept-Encoding < From': 1,
#   'Accept-Encoding < Host': 1,
#   'Accept-Encoding < User-Agent': 1,
#   'From < Host': 1,
#   'From < User-Agent': 1,
#   'Host < User-Agent': 1,
#   'Pragma < Accept': 1,
#   'Pragma < Accept-Encoding': 1,
#   'Pragma < From': 1,
#   'Pragma < Host': 1,
#   'Pragma < User-Agent': 1},
#  {'Accept < Accept-Encoding': 1,
#   'Accept < Accept-Language': 1,
#   'Accept < Referer': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Referer < Accept-Encoding': 1,
#   'Referer < Accept-Language': 1,
#   'Upgrade-Insecure-Requests < Accept': 1,
#   'Upgrade-Insecure-Requests < Accept-Encoding': 1,
#   'Upgrade-Insecure-Requests < Accept-Language': 1,
#   'Upgrade-Insecure-Requests < Referer': 1,
#   'Upgrade-Insecure-Requests < User-Agent': 1,
#   'User-Agent < Accept': 1,
#   'User-Agent < Accept-Encoding': 1,
#   'User-Agent < Accept-Language': 1,
#   'User-Agent < Referer': 1},
#  {'User-Agent < Accept-Encoding': 1},
#  {'Accept-Encoding < Accept': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Accept-Language < Accept': 1,
#   'From < Accept': 1,
#   'From < Accept-Encoding': 1,
#   'From < Accept-Language': 1,
#   'User-Agent < Accept': 1,
#   'User-Agent < Accept-Encoding': 1,
#   'User-Agent < Accept-Language': 1,
#   'User-Agent < From': 1},
#  {'Accept < Accept-Charset': 1,
#   'Accept-Encoding < Accept': 1,
#   'Accept-Encoding < Accept-Charset': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Accept-Language < Accept': 1,
#   'Accept-Language < Accept-Charset': 1},
#  {'Accept < Accept-Charset': 1,
#   'Accept-Encoding < Accept': 1,
#   'Accept-Encoding < Accept-Charset': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Accept-Language < Accept': 1,
#   'Accept-Language < Accept-Charset': 1},
#  {'Accept < Accept-Encoding': 1,
#   'Accept < Accept-Language': 1,
#   'Accept < Referer': 1,
#   'Accept < Upgrade-Insecure-Requests': 1,
#   'Accept < User-Agent': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Referer < Accept-Encoding': 1,
#   'Referer < Accept-Language': 1,
#   'Upgrade-Insecure-Requests < Accept-Encoding': 1,
#   'Upgrade-Insecure-Requests < Accept-Language': 1,
#   'Upgrade-Insecure-Requests < Referer': 1,
#   'Upgrade-Insecure-Requests < User-Agent': 1,
#   'User-Agent < Accept-Encoding': 1,
#   'User-Agent < Accept-Language': 1,
#   'User-Agent < Referer': 1},
#  {'Accept < Accept-Encoding': 1,
#   'Accept < User-Agent': 1,
#   'User-Agent < Accept-Encoding': 1},
#  {'Host < Referer': 1, 'Host < User-Agent': 1, 'Referer < User-Agent': 1},
#  {'Host < Referer': 1, 'Host < User-Agent': 1, 'Referer < User-Agent': 1},
#  {'Accept < Accept-Charset': 1,
#   'Accept-Encoding < Accept': 1,
#   'Accept-Encoding < Accept-Charset': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Accept-Language < Accept': 1,
#   'Accept-Language < Accept-Charset': 1},
#  {'Accept < Accept-Charset': 1,
#   'Accept-Encoding < Accept': 1,
#   'Accept-Encoding < Accept-Charset': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Accept-Language < Accept': 1,
#   'Accept-Language < Accept-Charset': 1},
#  {'Accept < Upgrade-Insecure-Requests': 1,
#   'Accept < User-Agent': 1,
#   'Accept-Encoding < Accept': 1,
#   'Accept-Encoding < Save-Data': 1,
#   'Accept-Encoding < Upgrade-Insecure-Requests': 1,
#   'Accept-Encoding < User-Agent': 1,
#   'Accept-Encoding < X-Forwarded-For': 1,
#   'Accept-Language < Accept': 1,
#   'Accept-Language < Accept-Encoding': 1,
#   'Accept-Language < Save-Data': 1,
#   'Accept-Language < Upgrade-Insecure-Requests': 1,
#   'Accept-Language < User-Agent': 1,
#   'Accept-Language < X-Forwarded-For': 1,
#   'Save-Data < Accept': 1,
#   'Save-Data < Upgrade-Insecure-Requests': 1,
#   'Save-Data < User-Agent': 1,
#   'Save-Data < X-Forwarded-For': 1,
#   'User-Agent < Upgrade-Insecure-Requests': 1,
#   'X-Forwarded-For < Accept': 1,
#   'X-Forwarded-For < Upgrade-Insecure-Requests': 1,
#   'X-Forwarded-For < User-Agent': 1},
#  {'Accept < Accept-Encoding': 1,
#   'Accept < From': 1,
#   'Accept < Host': 1,
#   'Accept < User-Agent': 1,
#   'Accept-Encoding < From': 1,
#   'Accept-Encoding < Host': 1,
#   'Accept-Encoding < User-Agent': 1,
#   'From < Host': 1,
#   'From < User-Agent': 1,
#   'Host < User-Agent': 1,
#   'Pragma < Accept': 1,
#   'Pragma < Accept-Encoding': 1,
#   'Pragma < From': 1,
#   'Pragma < Host': 1,
#   'Pragma < User-Agent': 1},
#  {'Accept < Accept-Encoding': 1,
#   'Accept < Host': 1,
#   'Accept < User-Agent': 1,
#   'Accept-Encoding < Host': 1,
#   'Accept-Encoding < User-Agent': 1,
#   'Host < User-Agent': 1,
#   'Pragma < Accept': 1,
#   'Pragma < Accept-Encoding': 1,
#   'Pragma < Host': 1,
#   'Pragma < User-Agent': 1},
#  {'Accept < Accept-Charset': 1,
#   'Accept-Encoding < Accept': 1,
#   'Accept-Encoding < Accept-Charset': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Accept-Language < Accept': 1,
#   'Accept-Language < Accept-Charset': 1},
#  {'Connection < User-Agent': 1},
#  {'Connection < User-Agent': 1},
#  {'Connection < User-Agent': 1},
#  {'Host < Referer': 1, 'Host < User-Agent': 1, 'Referer < User-Agent': 1},
#  {'Accept < Accept-Charset': 1,
#   'Accept-Encoding < Accept': 1,
#   'Accept-Encoding < Accept-Charset': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Accept-Language < Accept': 1,
#   'Accept-Language < Accept-Charset': 1},
#  {'Accept < Accept-Encoding': 1,
#   'Accept < Accept-Language': 1,
#   'Accept < Connection': 1,
#   'Accept < Referer': 1,
#   'Accept < Upgrade-Insecure-Requests': 1,
#   'Accept-Encoding < Connection': 1,
#   'Accept-Encoding < Referer': 1,
#   'Accept-Encoding < Upgrade-Insecure-Requests': 1,
#   'Accept-Language < Accept-Encoding': 1,
#   'Accept-Language < Connection': 1,
#   'Accept-Language < Referer': 1,
#   'Accept-Language < Upgrade-Insecure-Requests': 1,
#   'Connection < Upgrade-Insecure-Requests': 1,
#   'Referer < Connection': 1,
#   'Referer < Upgrade-Insecure-Requests': 1},
#  {'Accept < Accept-Charset': 1,
#   'Accept-Encoding < Accept': 1,
#   'Accept-Encoding < Accept-Charset': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Accept-Language < Accept': 1,
#   'Accept-Language < Accept-Charset': 1},
#  {'Accept < Accept-Charset': 1,
#   'Accept-Encoding < Accept': 1,
#   'Accept-Encoding < Accept-Charset': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Accept-Language < Accept': 1,
#   'Accept-Language < Accept-Charset': 1},
#  {'Accept < Accept-Charset': 1,
#   'Accept-Encoding < Accept': 1,
#   'Accept-Encoding < Accept-Charset': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Accept-Language < Accept': 1,
#   'Accept-Language < Accept-Charset': 1},
#  {'Accept < Accept-Charset': 1,
#   'Accept-Encoding < Accept': 1,
#   'Accept-Encoding < Accept-Charset': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Accept-Language < Accept': 1,
#   'Accept-Language < Accept-Charset': 1},
#  {'Accept-Encoding < Accept': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Accept-Language < Accept': 1,
#   'From < Accept': 1,
#   'From < Accept-Encoding': 1,
#   'From < Accept-Language': 1,
#   'User-Agent < Accept': 1,
#   'User-Agent < Accept-Encoding': 1,
#   'User-Agent < Accept-Language': 1,
#   'User-Agent < From': 1},
#  {'Accept < Accept-Encoding': 1},
#  {'Connection < User-Agent': 1},
#  {'Accept < Accept-Charset': 1,
#   'Accept-Encoding < Accept': 1,
#   'Accept-Encoding < Accept-Charset': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Accept-Language < Accept': 1,
#   'Accept-Language < Accept-Charset': 1},
#  {'Connection < User-Agent': 1},
#  {'Connection < User-Agent': 1},
#  {'Accept < Accept-Charset': 1,
#   'Accept-Encoding < Accept': 1,
#   'Accept-Encoding < Accept-Charset': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Accept-Language < Accept': 1,
#   'Accept-Language < Accept-Charset': 1},
#  {'Accept < Accept-Charset': 1,
#   'Accept-Encoding < Accept': 1,
#   'Accept-Encoding < Accept-Charset': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Accept-Language < Accept': 1,
#   'Accept-Language < Accept-Charset': 1},
#  {'Accept < Accept-Charset': 1,
#   'Accept-Encoding < Accept': 1,
#   'Accept-Encoding < Accept-Charset': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Accept-Language < Accept': 1,
#   'Accept-Language < Accept-Charset': 1},
#  {'Accept < Accept-Charset': 1,
#   'Accept-Encoding < Accept': 1,
#   'Accept-Encoding < Accept-Charset': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Accept-Language < Accept': 1,
#   'Accept-Language < Accept-Charset': 1},
#  {'Accept < Accept-Charset': 1,
#   'Accept-Encoding < Accept': 1,
#   'Accept-Encoding < Accept-Charset': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Accept-Language < Accept': 1,
#   'Accept-Language < Accept-Charset': 1},
#  {'Accept < Accept-Encoding': 1,
#   'Accept < Accept-Language': 1,
#   'Accept < Referer': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Referer < Accept-Encoding': 1,
#   'Referer < Accept-Language': 1,
#   'Upgrade-Insecure-Requests < Accept': 1,
#   'Upgrade-Insecure-Requests < Accept-Encoding': 1,
#   'Upgrade-Insecure-Requests < Accept-Language': 1,
#   'Upgrade-Insecure-Requests < Referer': 1,
#   'Upgrade-Insecure-Requests < User-Agent': 1,
#   'User-Agent < Accept': 1,
#   'User-Agent < Accept-Encoding': 1,
#   'User-Agent < Accept-Language': 1,
#   'User-Agent < Referer': 1},
#  {'Accept < Accept-Charset': 1,
#   'Accept < Accept-Encoding': 1,
#   'Accept < Accept-Language': 1,
#   'Accept-Encoding < Accept-Charset': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Accept-Language < Accept-Charset': 1},
#  {'Accept < Accept-Charset': 1,
#   'Accept < Accept-Encoding': 1,
#   'Accept < Accept-Language': 1,
#   'Accept-Encoding < Accept-Charset': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Accept-Language < Accept-Charset': 1},
#  {'Accept < Accept-Charset': 1,
#   'Accept-Encoding < Accept': 1,
#   'Accept-Encoding < Accept-Charset': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Accept-Language < Accept': 1,
#   'Accept-Language < Accept-Charset': 1},
#  {'Accept < Accept-Encoding': 1,
#   'Accept < Accept-Language': 1,
#   'Accept < Referer': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Referer < Accept-Encoding': 1,
#   'Referer < Accept-Language': 1,
#   'Upgrade-Insecure-Requests < Accept': 1,
#   'Upgrade-Insecure-Requests < Accept-Encoding': 1,
#   'Upgrade-Insecure-Requests < Accept-Language': 1,
#   'Upgrade-Insecure-Requests < Referer': 1,
#   'Upgrade-Insecure-Requests < User-Agent': 1,
#   'User-Agent < Accept': 1,
#   'User-Agent < Accept-Encoding': 1,
#   'User-Agent < Accept-Language': 1,
#   'User-Agent < Referer': 1},
#  {'Accept < Accept-Charset': 1,
#   'Accept-Encoding < Accept': 1,
#   'Accept-Encoding < Accept-Charset': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Accept-Language < Accept': 1,
#   'Accept-Language < Accept-Charset': 1},
#  {'Accept < Accept-Encoding': 1,
#   'Accept < Accept-Language': 1,
#   'Accept < Connection': 1,
#   'Accept < Dnt': 1,
#   'Accept < Referer': 1,
#   'Accept < Upgrade-Insecure-Requests': 1,
#   'Accept-Encoding < Connection': 1,
#   'Accept-Encoding < Dnt': 1,
#   'Accept-Encoding < Referer': 1,
#   'Accept-Encoding < Upgrade-Insecure-Requests': 1,
#   'Accept-Language < Accept-Encoding': 1,
#   'Accept-Language < Connection': 1,
#   'Accept-Language < Dnt': 1,
#   'Accept-Language < Referer': 1,
#   'Accept-Language < Upgrade-Insecure-Requests': 1,
#   'Connection < Upgrade-Insecure-Requests': 1,
#   'Dnt < Connection': 1,
#   'Dnt < Upgrade-Insecure-Requests': 1,
#   'Referer < Connection': 1,
#   'Referer < Dnt': 1,
#   'Referer < Upgrade-Insecure-Requests': 1},
#  {'Accept < Accept-Charset': 1,
#   'Accept < Accept-Encoding': 1,
#   'Accept < Accept-Language': 1,
#   'Accept-Encoding < Accept-Charset': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Accept-Language < Accept-Charset': 1},
#  {'Accept < Accept-Encoding': 1,
#   'Accept < User-Agent': 1,
#   'User-Agent < Accept-Encoding': 1},
#  {'Accept < Accept-Charset': 1,
#   'Accept < Accept-Encoding': 1,
#   'Accept < Accept-Language': 1,
#   'Accept-Encoding < Accept-Charset': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Accept-Language < Accept-Charset': 1},
#  {'Accept-Encoding < Accept': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Accept-Language < Accept': 1,
#   'From < Accept': 1,
#   'From < Accept-Encoding': 1,
#   'From < Accept-Language': 1,
#   'User-Agent < Accept': 1,
#   'User-Agent < Accept-Encoding': 1,
#   'User-Agent < Accept-Language': 1,
#   'User-Agent < From': 1},
#  {'Accept < Accept-Encoding': 1,
#   'Accept < From': 1,
#   'Accept < User-Agent': 1,
#   'From < Accept-Encoding': 1,
#   'From < User-Agent': 1,
#   'User-Agent < Accept-Encoding': 1},
#  {'Accept < Accept-Charset': 1,
#   'Accept-Encoding < Accept': 1,
#   'Accept-Encoding < Accept-Charset': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Accept-Language < Accept': 1,
#   'Accept-Language < Accept-Charset': 1},
#  {'Accept < Accept-Encoding': 1,
#   'Accept < From': 1,
#   'Accept < Host': 1,
#   'Accept < User-Agent': 1,
#   'Accept-Encoding < From': 1,
#   'Accept-Encoding < Host': 1,
#   'Accept-Encoding < User-Agent': 1,
#   'From < Host': 1,
#   'From < User-Agent': 1,
#   'Host < User-Agent': 1,
#   'Pragma < Accept': 1,
#   'Pragma < Accept-Encoding': 1,
#   'Pragma < From': 1,
#   'Pragma < Host': 1,
#   'Pragma < User-Agent': 1},
#  {'Accept < Accept-Charset': 1,
#   'Accept-Encoding < Accept': 1,
#   'Accept-Encoding < Accept-Charset': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Accept-Language < Accept': 1,
#   'Accept-Language < Accept-Charset': 1},
#  {'Accept < Accept-Encoding': 1,
#   'Accept < Accept-Language': 1,
#   'Accept < Connection': 1,
#   'Accept < Cookie': 1,
#   'Accept < Dnt': 1,
#   'Accept < Referer': 1,
#   'Accept < Upgrade-Insecure-Requests': 1,
#   'Accept-Encoding < Connection': 1,
#   'Accept-Encoding < Cookie': 1,
#   'Accept-Encoding < Dnt': 1,
#   'Accept-Encoding < Referer': 1,
#   'Accept-Encoding < Upgrade-Insecure-Requests': 1,
#   'Accept-Language < Accept-Encoding': 1,
#   'Accept-Language < Connection': 1,
#   'Accept-Language < Cookie': 1,
#   'Accept-Language < Dnt': 1,
#   'Accept-Language < Referer': 1,
#   'Accept-Language < Upgrade-Insecure-Requests': 1,
#   'Connection < Upgrade-Insecure-Requests': 1,
#   'Cookie < Connection': 1,
#   'Cookie < Dnt': 1,
#   'Cookie < Upgrade-Insecure-Requests': 1,
#   'Dnt < Connection': 1,
#   'Dnt < Upgrade-Insecure-Requests': 1,
#   'Referer < Connection': 1,
#   'Referer < Cookie': 1,
#   'Referer < Dnt': 1,
#   'Referer < Upgrade-Insecure-Requests': 1},
#  {'Accept < Accept-Encoding': 1,
#   'Accept < Accept-Language': 1,
#   'Accept < Connection': 1,
#   'Accept < Cookie': 1,
#   'Accept < Dnt': 1,
#   'Accept < Referer': 1,
#   'Accept < Upgrade-Insecure-Requests': 1,
#   'Accept-Encoding < Connection': 1,
#   'Accept-Encoding < Cookie': 1,
#   'Accept-Encoding < Dnt': 1,
#   'Accept-Encoding < Referer': 1,
#   'Accept-Encoding < Upgrade-Insecure-Requests': 1,
#   'Accept-Language < Accept-Encoding': 1,
#   'Accept-Language < Connection': 1,
#   'Accept-Language < Cookie': 1,
#   'Accept-Language < Dnt': 1,
#   'Accept-Language < Referer': 1,
#   'Accept-Language < Upgrade-Insecure-Requests': 1,
#   'Connection < Upgrade-Insecure-Requests': 1,
#   'Cookie < Connection': 1,
#   'Cookie < Dnt': 1,
#   'Cookie < Upgrade-Insecure-Requests': 1,
#   'Dnt < Connection': 1,
#   'Dnt < Upgrade-Insecure-Requests': 1,
#   'Referer < Connection': 1,
#   'Referer < Cookie': 1,
#   'Referer < Dnt': 1,
#   'Referer < Upgrade-Insecure-Requests': 1},
#  {'Accept < Accept-Charset': 1,
#   'Accept-Encoding < Accept': 1,
#   'Accept-Encoding < Accept-Charset': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Accept-Language < Accept': 1,
#   'Accept-Language < Accept-Charset': 1},
#  {'Accept < Accept-Encoding': 1,
#   'Accept < Accept-Language': 1,
#   'Accept < Connection': 1,
#   'Accept < Cookie': 1,
#   'Accept < Dnt': 1,
#   'Accept < Referer': 1,
#   'Accept < Upgrade-Insecure-Requests': 1,
#   'Accept-Encoding < Connection': 1,
#   'Accept-Encoding < Cookie': 1,
#   'Accept-Encoding < Dnt': 1,
#   'Accept-Encoding < Referer': 1,
#   'Accept-Encoding < Upgrade-Insecure-Requests': 1,
#   'Accept-Language < Accept-Encoding': 1,
#   'Accept-Language < Connection': 1,
#   'Accept-Language < Cookie': 1,
#   'Accept-Language < Dnt': 1,
#   'Accept-Language < Referer': 1,
#   'Accept-Language < Upgrade-Insecure-Requests': 1,
#   'Connection < Upgrade-Insecure-Requests': 1,
#   'Cookie < Connection': 1,
#   'Cookie < Dnt': 1,
#   'Cookie < Upgrade-Insecure-Requests': 1,
#   'Dnt < Connection': 1,
#   'Dnt < Upgrade-Insecure-Requests': 1,
#   'Referer < Connection': 1,
#   'Referer < Cookie': 1,
#   'Referer < Dnt': 1,
#   'Referer < Upgrade-Insecure-Requests': 1},
#  {'Accept < Accept-Encoding': 1,
#   'Accept < Accept-Language': 1,
#   'Accept < Connection': 1,
#   'Accept-Encoding < Connection': 1,
#   'Accept-Language < Accept-Encoding': 1,
#   'Accept-Language < Connection': 1,
#   'Origin < Accept': 1,
#   'Origin < Accept-Encoding': 1,
#   'Origin < Accept-Language': 1,
#   'Origin < Connection': 1,
#   'Origin < Referer': 1,
#   'Origin < X-Requested-With': 1,
#   'Referer < Accept': 1,
#   'Referer < Accept-Encoding': 1,
#   'Referer < Accept-Language': 1,
#   'Referer < Connection': 1,
#   'User-Agent < Accept': 1,
#   'User-Agent < Accept-Encoding': 1,
#   'User-Agent < Accept-Language': 1,
#   'User-Agent < Connection': 1,
#   'User-Agent < Origin': 1,
#   'User-Agent < Referer': 1,
#   'User-Agent < X-Requested-With': 1,
#   'X-Requested-With < Accept': 1,
#   'X-Requested-With < Accept-Encoding': 1,
#   'X-Requested-With < Accept-Language': 1,
#   'X-Requested-With < Connection': 1,
#   'X-Requested-With < Referer': 1},
#  {'Accept < Accept-Encoding': 1,
#   'Accept < Accept-Language': 1,
#   'Accept < Connection': 1,
#   'Accept < Cookie': 1,
#   'Accept < Dnt': 1,
#   'Accept < Referer': 1,
#   'Accept < Upgrade-Insecure-Requests': 1,
#   'Accept-Encoding < Connection': 1,
#   'Accept-Encoding < Cookie': 1,
#   'Accept-Encoding < Dnt': 1,
#   'Accept-Encoding < Referer': 1,
#   'Accept-Encoding < Upgrade-Insecure-Requests': 1,
#   'Accept-Language < Accept-Encoding': 1,
#   'Accept-Language < Connection': 1,
#   'Accept-Language < Cookie': 1,
#   'Accept-Language < Dnt': 1,
#   'Accept-Language < Referer': 1,
#   'Accept-Language < Upgrade-Insecure-Requests': 1,
#   'Connection < Upgrade-Insecure-Requests': 1,
#   'Cookie < Connection': 1,
#   'Cookie < Dnt': 1,
#   'Cookie < Upgrade-Insecure-Requests': 1,
#   'Dnt < Connection': 1,
#   'Dnt < Upgrade-Insecure-Requests': 1,
#   'Referer < Connection': 1,
#   'Referer < Cookie': 1,
#   'Referer < Dnt': 1,
#   'Referer < Upgrade-Insecure-Requests': 1},
#  {'Accept < Accept-Charset': 1,
#   'Accept-Encoding < Accept': 1,
#   'Accept-Encoding < Accept-Charset': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Accept-Language < Accept': 1,
#   'Accept-Language < Accept-Charset': 1},
#  {'User-Agent < Accept-Encoding': 1},
#  {'Accept < Accept-Charset': 1,
#   'Accept-Encoding < Accept': 1,
#   'Accept-Encoding < Accept-Charset': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Accept-Language < Accept': 1,
#   'Accept-Language < Accept-Charset': 1},
#  {'Accept-Encoding < Accept': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Accept-Language < Accept': 1,
#   'From < Accept': 1,
#   'From < Accept-Encoding': 1,
#   'From < Accept-Language': 1,
#   'User-Agent < Accept': 1,
#   'User-Agent < Accept-Encoding': 1,
#   'User-Agent < Accept-Language': 1,
#   'User-Agent < From': 1},
#  {'Accept < Accept-Encoding': 1,
#   'Accept < From': 1,
#   'Accept < User-Agent': 1,
#   'From < Accept-Encoding': 1,
#   'From < User-Agent': 1,
#   'User-Agent < Accept-Encoding': 1},
#  {'Accept < Accept-Charset': 1,
#   'Accept-Encoding < Accept': 1,
#   'Accept-Encoding < Accept-Charset': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Accept-Language < Accept': 1,
#   'Accept-Language < Accept-Charset': 1},
#  {'Accept < Accept-Encoding': 1,
#   'Accept < Accept-Language': 1,
#   'Accept < Referer': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Referer < Accept-Encoding': 1,
#   'Referer < Accept-Language': 1,
#   'Upgrade-Insecure-Requests < Accept': 1,
#   'Upgrade-Insecure-Requests < Accept-Encoding': 1,
#   'Upgrade-Insecure-Requests < Accept-Language': 1,
#   'Upgrade-Insecure-Requests < Referer': 1,
#   'Upgrade-Insecure-Requests < User-Agent': 1,
#   'User-Agent < Accept': 1,
#   'User-Agent < Accept-Encoding': 1,
#   'User-Agent < Accept-Language': 1,
#   'User-Agent < Referer': 1},
#  {'Accept < Cache-Control': 1,
#   'Accept < Pragma': 1,
#   'Pragma < Cache-Control': 1},
#  {'Accept-Encoding < Connection': 1,
#   'Accept-Encoding < User-Agent': 1,
#   'Accept-Language < Accept-Encoding': 1,
#   'Accept-Language < Connection': 1,
#   'Accept-Language < User-Agent': 1,
#   'Connection < User-Agent': 1},
#  {'Accept-Language < Connection': 1,
#   'Accept-Language < Dnt': 1,
#   'Accept-Language < Host': 1,
#   'Accept-Language < User-Agent': 1,
#   'Connection < Dnt': 1,
#   'Connection < Host': 1,
#   'Connection < User-Agent': 1,
#   'Dnt < Host': 1,
#   'Dnt < User-Agent': 1,
#   'Host < User-Agent': 1},
#  {'Accept-Encoding < Connection': 1,
#   'Accept-Encoding < User-Agent': 1,
#   'Accept-Language < Accept-Encoding': 1,
#   'Accept-Language < Connection': 1,
#   'Accept-Language < User-Agent': 1,
#   'Connection < User-Agent': 1},
#  {'Accept < Accept-Encoding': 1,
#   'Accept < Accept-Language': 1,
#   'Accept < Connection': 1,
#   'Accept < Referer': 1,
#   'Accept < Upgrade-Insecure-Requests': 1,
#   'Accept-Encoding < Connection': 1,
#   'Accept-Encoding < Referer': 1,
#   'Accept-Encoding < Upgrade-Insecure-Requests': 1,
#   'Accept-Language < Accept-Encoding': 1,
#   'Accept-Language < Connection': 1,
#   'Accept-Language < Referer': 1,
#   'Accept-Language < Upgrade-Insecure-Requests': 1,
#   'Connection < Upgrade-Insecure-Requests': 1,
#   'Referer < Connection': 1,
#   'Referer < Upgrade-Insecure-Requests': 1},
#  {'Accept < Accept-Charset': 1,
#   'Accept-Encoding < Accept': 1,
#   'Accept-Encoding < Accept-Charset': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Accept-Language < Accept': 1,
#   'Accept-Language < Accept-Charset': 1},
#  {'User-Agent < Accept-Encoding': 1},
#  {'Accept < Accept-Encoding': 1,
#   'Accept < From': 1,
#   'Accept < Host': 1,
#   'Accept < User-Agent': 1,
#   'Accept-Encoding < From': 1,
#   'Accept-Encoding < Host': 1,
#   'Accept-Encoding < User-Agent': 1,
#   'From < Host': 1,
#   'From < User-Agent': 1,
#   'Host < User-Agent': 1,
#   'Pragma < Accept': 1,
#   'Pragma < Accept-Encoding': 1,
#   'Pragma < From': 1,
#   'Pragma < Host': 1,
#   'Pragma < User-Agent': 1},
#  {'Accept-Encoding < Connection': 1,
#   'Accept-Encoding < Dnt': 1,
#   'Accept-Encoding < Host': 1,
#   'Accept-Language < Accept-Encoding': 1,
#   'Accept-Language < Connection': 1,
#   'Accept-Language < Dnt': 1,
#   'Accept-Language < Host': 1,
#   'Accept-Language < User-Agent': 1,
#   'Dnt < Connection': 1,
#   'Host < Connection': 1,
#   'Host < Dnt': 1,
#   'User-Agent < Accept-Encoding': 1,
#   'User-Agent < Connection': 1,
#   'User-Agent < Dnt': 1,
#   'User-Agent < Host': 1},
#  {'Accept < Accept-Encoding': 1,
#   'Accept < From': 1,
#   'Accept < Host': 1,
#   'Accept < User-Agent': 1,
#   'Accept-Encoding < From': 1,
#   'Accept-Encoding < Host': 1,
#   'Accept-Encoding < User-Agent': 1,
#   'From < Host': 1,
#   'From < User-Agent': 1,
#   'Host < User-Agent': 1,
#   'Pragma < Accept': 1,
#   'Pragma < Accept-Encoding': 1,
#   'Pragma < From': 1,
#   'Pragma < Host': 1,
#   'Pragma < User-Agent': 1},
#  {'Accept < Accept-Encoding': 1,
#   'Accept < Accept-Language': 1,
#   'Accept < Referer': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Referer < Accept-Encoding': 1,
#   'Referer < Accept-Language': 1,
#   'Upgrade-Insecure-Requests < Accept': 1,
#   'Upgrade-Insecure-Requests < Accept-Encoding': 1,
#   'Upgrade-Insecure-Requests < Accept-Language': 1,
#   'Upgrade-Insecure-Requests < Referer': 1,
#   'Upgrade-Insecure-Requests < User-Agent': 1,
#   'User-Agent < Accept': 1,
#   'User-Agent < Accept-Encoding': 1,
#   'User-Agent < Accept-Language': 1,
#   'User-Agent < Referer': 1},
#  {'Accept < Accept-Charset': 1,
#   'Accept-Encoding < Accept': 1,
#   'Accept-Encoding < Accept-Charset': 1},
#  {'Accept < Accept-Encoding': 1,
#   'Accept < Accept-Language': 1,
#   'Accept < Referer': 1,
#   'Accept < User-Agent': 1,
#   'Accept-Language < Accept-Encoding': 1,
#   'Referer < Accept-Encoding': 1,
#   'Referer < Accept-Language': 1,
#   'Upgrade-Insecure-Requests < Accept': 1,
#   'Upgrade-Insecure-Requests < Accept-Encoding': 1,
#   'Upgrade-Insecure-Requests < Accept-Language': 1,
#   'Upgrade-Insecure-Requests < Referer': 1,
#   'Upgrade-Insecure-Requests < User-Agent': 1,
#   'User-Agent < Accept-Encoding': 1,
#   'User-Agent < Accept-Language': 1,
#   'User-Agent < Referer': 1},
#  {'Accept < Accept-Encoding': 1,
#   'Accept < Accept-Language': 1,
#   'Accept < Connection': 1,
#   'Accept-Encoding < Connection': 1,
#   'Accept-Language < Accept-Encoding': 1,
#   'Accept-Language < Connection': 1,
#   'Origin < Accept': 1,
#   'Origin < Accept-Encoding': 1,
#   'Origin < Accept-Language': 1,
#   'Origin < Connection': 1,
#   'Origin < Referer': 1,
#   'Origin < X-Requested-With': 1,
#   'Referer < Accept': 1,
#   'Referer < Accept-Encoding': 1,
#   'Referer < Accept-Language': 1,
#   'Referer < Connection': 1,
#   'User-Agent < Accept': 1,
#   'User-Agent < Accept-Encoding': 1,
#   'User-Agent < Accept-Language': 1,
#   'User-Agent < Connection': 1,
#   'User-Agent < Origin': 1,
#   'User-Agent < Referer': 1,
#   'User-Agent < X-Requested-With': 1,
#   'X-Requested-With < Accept': 1,
#   'X-Requested-With < Accept-Encoding': 1,
#   'X-Requested-With < Accept-Language': 1,
#   'X-Requested-With < Connection': 1,
#   'X-Requested-With < Referer': 1},
#  {'Accept < Accept-Charset': 1,
#   'Accept-Encoding < Accept': 1,
#   'Accept-Encoding < Accept-Charset': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Accept-Language < Accept': 1,
#   'Accept-Language < Accept-Charset': 1},
#  {'Accept < Accept-Charset': 1,
#   'Accept-Encoding < Accept': 1,
#   'Accept-Encoding < Accept-Charset': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Accept-Language < Accept': 1,
#   'Accept-Language < Accept-Charset': 1},
#  {'Accept-Encoding < User-Agent': 1},
#  {'Accept-Encoding < Accept': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Accept-Language < Accept': 1,
#   'From < Accept': 1,
#   'From < Accept-Encoding': 1,
#   'From < Accept-Language': 1,
#   'User-Agent < Accept': 1,
#   'User-Agent < Accept-Encoding': 1,
#   'User-Agent < Accept-Language': 1,
#   'User-Agent < From': 1},
#  {'Accept < Accept-Encoding': 1,
#   'Accept < From': 1,
#   'Accept < Host': 1,
#   'Accept < If-Modified-Since': 1,
#   'Accept < User-Agent': 1,
#   'Accept-Encoding < From': 1,
#   'Accept-Encoding < Host': 1,
#   'Accept-Encoding < If-Modified-Since': 1,
#   'Accept-Encoding < User-Agent': 1,
#   'From < Host': 1,
#   'From < If-Modified-Since': 1,
#   'From < User-Agent': 1,
#   'Host < If-Modified-Since': 1,
#   'Host < User-Agent': 1,
#   'If-Modified-Since < User-Agent': 1,
#   'Pragma < Accept': 1,
#   'Pragma < Accept-Encoding': 1,
#   'Pragma < From': 1,
#   'Pragma < Host': 1,
#   'Pragma < If-Modified-Since': 1,
#   'Pragma < User-Agent': 1},
#  {'Accept < Accept-Encoding': 1,
#   'Accept < From': 1,
#   'Accept < Host': 1,
#   'Accept < User-Agent': 1,
#   'Accept-Encoding < From': 1,
#   'Accept-Encoding < Host': 1,
#   'Accept-Encoding < User-Agent': 1,
#   'From < Host': 1,
#   'From < User-Agent': 1,
#   'Host < User-Agent': 1,
#   'Pragma < Accept': 1,
#   'Pragma < Accept-Encoding': 1,
#   'Pragma < From': 1,
#   'Pragma < Host': 1,
#   'Pragma < User-Agent': 1},
#  {'Accept-Encoding < User-Agent': 1},
#  {'Accept < Accept-Encoding': 1,
#   'Accept < From': 1,
#   'Accept < Host': 1,
#   'Accept < User-Agent': 1,
#   'Accept-Encoding < From': 1,
#   'Accept-Encoding < Host': 1,
#   'Accept-Encoding < User-Agent': 1,
#   'From < Host': 1,
#   'From < User-Agent': 1,
#   'Host < User-Agent': 1,
#   'Pragma < Accept': 1,
#   'Pragma < Accept-Encoding': 1,
#   'Pragma < From': 1,
#   'Pragma < Host': 1,
#   'Pragma < User-Agent': 1},
#  {'Accept < Accept-Charset': 1,
#   'Accept-Encoding < Accept': 1,
#   'Accept-Encoding < Accept-Charset': 1},
#  {'Accept < Accept-Encoding': 1,
#   'Accept < From': 1,
#   'Accept < Host': 1,
#   'Accept < User-Agent': 1,
#   'Accept-Encoding < From': 1,
#   'Accept-Encoding < Host': 1,
#   'Accept-Encoding < User-Agent': 1,
#   'From < Host': 1,
#   'From < User-Agent': 1,
#   'Host < User-Agent': 1,
#   'Pragma < Accept': 1,
#   'Pragma < Accept-Encoding': 1,
#   'Pragma < From': 1,
#   'Pragma < Host': 1,
#   'Pragma < User-Agent': 1},
#  {'Host < Connection': 1},
#  {'User-Agent < Host': 1},
#  {'Accept < Accept-Encoding': 1,
#   'Accept < Accept-Language': 1,
#   'Accept < Referer': 1,
#   'Accept < User-Agent': 1,
#   'Accept-Language < Accept-Encoding': 1,
#   'Referer < Accept-Encoding': 1,
#   'Referer < Accept-Language': 1,
#   'Upgrade-Insecure-Requests < Accept': 1,
#   'Upgrade-Insecure-Requests < Accept-Encoding': 1,
#   'Upgrade-Insecure-Requests < Accept-Language': 1,
#   'Upgrade-Insecure-Requests < Referer': 1,
#   'Upgrade-Insecure-Requests < User-Agent': 1,
#   'User-Agent < Accept-Encoding': 1,
#   'User-Agent < Accept-Language': 1,
#   'User-Agent < Referer': 1},
#  {'Accept < Accept-Encoding': 1,
#   'Accept < From': 1,
#   'Accept < Host': 1,
#   'Accept < User-Agent': 1,
#   'Accept-Encoding < From': 1,
#   'Accept-Encoding < Host': 1,
#   'Accept-Encoding < User-Agent': 1,
#   'From < Host': 1,
#   'From < User-Agent': 1,
#   'Host < User-Agent': 1,
#   'Pragma < Accept': 1,
#   'Pragma < Accept-Encoding': 1,
#   'Pragma < From': 1,
#   'Pragma < Host': 1,
#   'Pragma < User-Agent': 1},
#  {'Accept < Accept-Encoding': 1,
#   'Accept < Accept-Language': 1,
#   'Accept < Referer': 1,
#   'Accept < User-Agent': 1,
#   'Accept-Language < Accept-Encoding': 1,
#   'Referer < Accept-Encoding': 1,
#   'Referer < Accept-Language': 1,
#   'Upgrade-Insecure-Requests < Accept': 1,
#   'Upgrade-Insecure-Requests < Accept-Encoding': 1,
#   'Upgrade-Insecure-Requests < Accept-Language': 1,
#   'Upgrade-Insecure-Requests < Referer': 1,
#   'Upgrade-Insecure-Requests < User-Agent': 1,
#   'User-Agent < Accept-Encoding': 1,
#   'User-Agent < Accept-Language': 1,
#   'User-Agent < Referer': 1},
#  {'Accept < Accept-Encoding': 1,
#   'Accept < From': 1,
#   'Accept < User-Agent': 1,
#   'From < Accept-Encoding': 1,
#   'From < User-Agent': 1,
#   'User-Agent < Accept-Encoding': 1},
#  {'Host < Referer': 1, 'Host < User-Agent': 1, 'Referer < User-Agent': 1},
#  {'Accept < Accept-Charset': 1,
#   'Accept-Encoding < Accept': 1,
#   'Accept-Encoding < Accept-Charset': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Accept-Language < Accept': 1,
#   'Accept-Language < Accept-Charset': 1},
#  {'Accept < Accept-Encoding': 1,
#   'Accept < From': 1,
#   'Accept < User-Agent': 1,
#   'From < Accept-Encoding': 1,
#   'From < User-Agent': 1,
#   'User-Agent < Accept-Encoding': 1},
#  {'Accept < Accept-Encoding': 1,
#   'Accept < From': 1,
#   'Accept < Host': 1,
#   'Accept < User-Agent': 1,
#   'Accept-Encoding < From': 1,
#   'Accept-Encoding < Host': 1,
#   'Accept-Encoding < User-Agent': 1,
#   'From < Host': 1,
#   'From < User-Agent': 1,
#   'Host < User-Agent': 1,
#   'Pragma < Accept': 1,
#   'Pragma < Accept-Encoding': 1,
#   'Pragma < From': 1,
#   'Pragma < Host': 1,
#   'Pragma < User-Agent': 1},
#  {'Accept < Accept-Charset': 1,
#   'Accept-Encoding < Accept': 1,
#   'Accept-Encoding < Accept-Charset': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Accept-Language < Accept': 1,
#   'Accept-Language < Accept-Charset': 1},
#  {'Accept < Accept-Charset': 1,
#   'Accept-Encoding < Accept': 1,
#   'Accept-Encoding < Accept-Charset': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Accept-Language < Accept': 1,
#   'Accept-Language < Accept-Charset': 1},
#  {'Accept < Accept-Charset': 1,
#   'Accept-Encoding < Accept': 1,
#   'Accept-Encoding < Accept-Charset': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Accept-Language < Accept': 1,
#   'Accept-Language < Accept-Charset': 1},
#  {'Accept < Accept-Encoding': 1,
#   'Accept < From': 1,
#   'Accept < Host': 1,
#   'Accept < User-Agent': 1,
#   'Accept-Encoding < From': 1,
#   'Accept-Encoding < Host': 1,
#   'Accept-Encoding < User-Agent': 1,
#   'From < Host': 1,
#   'From < User-Agent': 1,
#   'Host < User-Agent': 1,
#   'Pragma < Accept': 1,
#   'Pragma < Accept-Encoding': 1,
#   'Pragma < From': 1,
#   'Pragma < Host': 1,
#   'Pragma < User-Agent': 1},
#  {'Accept-Encoding < User-Agent': 1},
#  {'Accept < Accept-Charset': 1,
#   'Accept-Encoding < Accept': 1,
#   'Accept-Encoding < Accept-Charset': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Accept-Language < Accept': 1,
#   'Accept-Language < Accept-Charset': 1},
#  {'Accept < Accept-Encoding': 1,
#   'Accept < From': 1,
#   'Accept < Host': 1,
#   'Accept < If-Modified-Since': 1,
#   'Accept < User-Agent': 1,
#   'Accept-Encoding < From': 1,
#   'Accept-Encoding < Host': 1,
#   'Accept-Encoding < If-Modified-Since': 1,
#   'Accept-Encoding < User-Agent': 1,
#   'From < Host': 1,
#   'From < If-Modified-Since': 1,
#   'From < User-Agent': 1,
#   'Host < If-Modified-Since': 1,
#   'Host < User-Agent': 1,
#   'If-Modified-Since < User-Agent': 1,
#   'Pragma < Accept': 1,
#   'Pragma < Accept-Encoding': 1,
#   'Pragma < From': 1,
#   'Pragma < Host': 1,
#   'Pragma < If-Modified-Since': 1,
#   'Pragma < User-Agent': 1},
#  {'Accept-Encoding < Accept': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Accept-Language < Accept': 1,
#   'From < Accept': 1,
#   'From < Accept-Encoding': 1,
#   'From < Accept-Language': 1,
#   'User-Agent < Accept': 1,
#   'User-Agent < Accept-Encoding': 1,
#   'User-Agent < Accept-Language': 1,
#   'User-Agent < From': 1},
#  {'Accept < Accept-Encoding': 1,
#   'Accept < From': 1,
#   'Accept < User-Agent': 1,
#   'From < Accept-Encoding': 1,
#   'From < User-Agent': 1,
#   'User-Agent < Accept-Encoding': 1},
#  {'Accept < Accept-Charset': 1,
#   'Accept-Encoding < Accept': 1,
#   'Accept-Encoding < Accept-Charset': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Accept-Language < Accept': 1,
#   'Accept-Language < Accept-Charset': 1},
#  {'Accept < Accept-Encoding': 1,
#   'Accept < From': 1,
#   'Accept < Host': 1,
#   'Accept < User-Agent': 1,
#   'Accept-Encoding < From': 1,
#   'Accept-Encoding < Host': 1,
#   'Accept-Encoding < User-Agent': 1,
#   'From < Host': 1,
#   'From < User-Agent': 1,
#   'Host < User-Agent': 1,
#   'Pragma < Accept': 1,
#   'Pragma < Accept-Encoding': 1,
#   'Pragma < From': 1,
#   'Pragma < Host': 1,
#   'Pragma < User-Agent': 1},
#  {'Accept-Encoding < User-Agent': 1},
#  {'Accept < Accept-Encoding': 1,
#   'Accept < From': 1,
#   'Accept < Host': 1,
#   'Accept < User-Agent': 1,
#   'Accept-Encoding < From': 1,
#   'Accept-Encoding < Host': 1,
#   'Accept-Encoding < User-Agent': 1,
#   'From < Host': 1,
#   'From < User-Agent': 1,
#   'Host < User-Agent': 1,
#   'Pragma < Accept': 1,
#   'Pragma < Accept-Encoding': 1,
#   'Pragma < From': 1,
#   'Pragma < Host': 1,
#   'Pragma < User-Agent': 1},
#  {'User-Agent < Accept-Encoding': 1},
#  {'Accept < Accept-Charset': 1,
#   'Accept-Encoding < Accept': 1,
#   'Accept-Encoding < Accept-Charset': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Accept-Language < Accept': 1,
#   'Accept-Language < Accept-Charset': 1},
#  {'Accept < Accept-Encoding': 1,
#   'Accept < From': 1,
#   'Accept < Host': 1,
#   'Accept < User-Agent': 1,
#   'Accept-Encoding < From': 1,
#   'Accept-Encoding < Host': 1,
#   'Accept-Encoding < User-Agent': 1,
#   'From < Host': 1,
#   'From < User-Agent': 1,
#   'Host < User-Agent': 1,
#   'Pragma < Accept': 1,
#   'Pragma < Accept-Encoding': 1,
#   'Pragma < From': 1,
#   'Pragma < Host': 1,
#   'Pragma < User-Agent': 1},
#  {'Accept < Accept-Encoding': 1,
#   'Accept < From': 1,
#   'Accept < Host': 1,
#   'Accept < User-Agent': 1,
#   'Accept-Encoding < From': 1,
#   'Accept-Encoding < Host': 1,
#   'Accept-Encoding < User-Agent': 1,
#   'From < Host': 1,
#   'From < User-Agent': 1,
#   'Host < User-Agent': 1,
#   'Pragma < Accept': 1,
#   'Pragma < Accept-Encoding': 1,
#   'Pragma < From': 1,
#   'Pragma < Host': 1,
#   'Pragma < User-Agent': 1},
#  {'Accept < Accept-Encoding': 1,
#   'Accept < From': 1,
#   'Accept < Host': 1,
#   'Accept < User-Agent': 1,
#   'Accept-Encoding < From': 1,
#   'Accept-Encoding < Host': 1,
#   'Accept-Encoding < User-Agent': 1,
# ...
#   'X-Compress < Connection': 1,
#   'X-Compress < Upgrade-Insecure-Requests': 1},
#  {'Accept-Encoding < Accept': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Accept-Language < Accept': 1,
#   'From < Accept': 1,
#   'From < Accept-Encoding': 1,
#   'From < Accept-Language': 1,
#   'User-Agent < Accept': 1,
#   'User-Agent < Accept-Encoding': 1,
#   'User-Agent < Accept-Language': 1,
#   'User-Agent < From': 1},
#  {'Accept < Accept-Encoding': 1,
#   'Accept < Accept-Language': 1,
#   'Accept < Dnt': 1,
#   'Accept < Referer': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Dnt < Accept-Encoding': 1,
#   'Dnt < Accept-Language': 1,
#   'Dnt < Referer': 1,
#   'Referer < Accept-Encoding': 1,
#   'Referer < Accept-Language': 1,
#   'Upgrade-Insecure-Requests < Accept': 1,
#   'Upgrade-Insecure-Requests < Accept-Encoding': 1,
#   'Upgrade-Insecure-Requests < Accept-Language': 1,
#   'Upgrade-Insecure-Requests < Dnt': 1,
#   'Upgrade-Insecure-Requests < Referer': 1,
#   'Upgrade-Insecure-Requests < User-Agent': 1,
#   'User-Agent < Accept': 1,
#   'User-Agent < Accept-Encoding': 1,
#   'User-Agent < Accept-Language': 1,
#   'User-Agent < Dnt': 1,
#   'User-Agent < Referer': 1},
#  {'Accept < Accept-Encoding': 1,
#   'Accept < Accept-Language': 1,
#   'Accept < Referer': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Referer < Accept-Encoding': 1,
#   'Referer < Accept-Language': 1,
#   'Upgrade-Insecure-Requests < Accept': 1,
#   'Upgrade-Insecure-Requests < Accept-Encoding': 1,
#   'Upgrade-Insecure-Requests < Accept-Language': 1,
#   'Upgrade-Insecure-Requests < Referer': 1,
#   'Upgrade-Insecure-Requests < User-Agent': 1,
#   'User-Agent < Accept': 1,
#   'User-Agent < Accept-Encoding': 1,
#   'User-Agent < Accept-Language': 1,
#   'User-Agent < Referer': 1},
#  {'Accept-Encoding < Accept': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Accept-Language < Accept': 1,
#   'From < Accept': 1,
#   'From < Accept-Encoding': 1,
#   'From < Accept-Language': 1,
#   'User-Agent < Accept': 1,
#   'User-Agent < Accept-Encoding': 1,
#   'User-Agent < Accept-Language': 1,
#   'User-Agent < From': 1},
#  {'Accept < Accept-Encoding': 1,
#   'Accept < From': 1,
#   'Accept < Host': 1,
#   'Accept < User-Agent': 1,
#   'Accept-Encoding < From': 1,
#   'Accept-Encoding < Host': 1,
#   'Accept-Encoding < User-Agent': 1,
#   'From < Host': 1,
#   'From < User-Agent': 1,
#   'Host < User-Agent': 1,
#   'Pragma < Accept': 1,
#   'Pragma < Accept-Encoding': 1,
#   'Pragma < From': 1,
#   'Pragma < Host': 1,
#   'Pragma < User-Agent': 1},
#  {'Accept < Accept-Charset': 1,
#   'Accept-Encoding < Accept': 1,
#   'Accept-Encoding < Accept-Charset': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Accept-Language < Accept': 1,
#   'Accept-Language < Accept-Charset': 1},
#  {'Accept < Accept-Encoding': 1,
#   'Accept < From': 1,
#   'Accept < Host': 1,
#   'Accept < User-Agent': 1,
#   'Accept-Encoding < From': 1,
#   'Accept-Encoding < Host': 1,
#   'Accept-Encoding < User-Agent': 1,
#   'From < Host': 1,
#   'From < User-Agent': 1,
#   'Host < User-Agent': 1,
#   'Pragma < Accept': 1,
#   'Pragma < Accept-Encoding': 1,
#   'Pragma < From': 1,
#   'Pragma < Host': 1,
#   'Pragma < User-Agent': 1},
#  {'Accept < Accept-Charset': 1,
#   'Accept-Encoding < Accept': 1,
#   'Accept-Encoding < Accept-Charset': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Accept-Language < Accept': 1,
#   'Accept-Language < Accept-Charset': 1},
#  {'Accept < Accept-Language': 1,
#   'Accept < Cache-Control': 1,
#   'Accept < Connection': 1,
#   'Accept < Referer': 1,
#   'Accept < X-Compress': 1,
#   'Accept < X-Moz': 1,
#   'Accept-Language < Cache-Control': 1,
#   'Accept-Language < Connection': 1,
#   'Accept-Language < Referer': 1,
#   'Accept-Language < X-Compress': 1,
#   'Accept-Language < X-Moz': 1,
#   'Cache-Control < Connection': 1,
#   'Host < Accept': 1,
#   'Host < Accept-Language': 1,
#   'Host < Cache-Control': 1,
#   'Host < Connection': 1,
#   'Host < Referer': 1,
#   'Host < X-Compress': 1,
#   'Host < X-Moz': 1,
#   'Referer < Cache-Control': 1,
#   'Referer < Connection': 1,
#   'Referer < X-Compress': 1,
#   'Referer < X-Moz': 1,
#   'User-Agent < Accept': 1,
#   'User-Agent < Accept-Language': 1,
#   'User-Agent < Cache-Control': 1,
#   'User-Agent < Connection': 1,
#   'User-Agent < Host': 1,
#   'User-Agent < Referer': 1,
#   'User-Agent < X-Compress': 1,
#   'User-Agent < X-Moz': 1,
#   'X-Compress < Cache-Control': 1,
#   'X-Compress < Connection': 1,
#   'X-Moz < Cache-Control': 1,
#   'X-Moz < Connection': 1,
#   'X-Moz < X-Compress': 1},
#  {'Accept < Accept-Encoding': 1,
#   'Accept < From': 1,
#   'Accept < User-Agent': 1,
#   'From < Accept-Encoding': 1,
#   'From < User-Agent': 1,
#   'User-Agent < Accept-Encoding': 1},
#  {'Accept < Accept-Encoding': 1,
#   'Accept < Accept-Language': 1,
#   'Accept < Referer': 1,
#   'Accept < User-Agent': 1,
#   'Accept-Language < Accept-Encoding': 1,
#   'Referer < Accept-Encoding': 1,
#   'Referer < Accept-Language': 1,
#   'Upgrade-Insecure-Requests < Accept': 1,
#   'Upgrade-Insecure-Requests < Accept-Encoding': 1,
#   'Upgrade-Insecure-Requests < Accept-Language': 1,
#   'Upgrade-Insecure-Requests < Referer': 1,
#   'Upgrade-Insecure-Requests < User-Agent': 1,
#   'User-Agent < Accept-Encoding': 1,
#   'User-Agent < Accept-Language': 1,
#   'User-Agent < Referer': 1},
#  {'Accept < Accept-Charset': 1,
#   'Accept-Encoding < Accept': 1,
#   'Accept-Encoding < Accept-Charset': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Accept-Language < Accept': 1,
#   'Accept-Language < Accept-Charset': 1},
#  {'Accept-Encoding < Accept': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Accept-Language < Accept': 1,
#   'User-Agent < Accept': 1,
#   'User-Agent < Accept-Encoding': 1,
#   'User-Agent < Accept-Language': 1},
#  {'Host < Connection': 1,
#   'User-Agent < Connection': 1,
#   'User-Agent < Host': 1},
#  {'Accept < Accept-Charset': 1,
#   'Accept-Encoding < Accept': 1,
#   'Accept-Encoding < Accept-Charset': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Accept-Language < Accept': 1,
#   'Accept-Language < Accept-Charset': 1},
#  {'Accept < Accept-Encoding': 1,
#   'Accept < Accept-Language': 1,
#   'Accept < Referer': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Referer < Accept-Encoding': 1,
#   'Referer < Accept-Language': 1,
#   'Upgrade-Insecure-Requests < Accept': 1,
#   'Upgrade-Insecure-Requests < Accept-Encoding': 1,
#   'Upgrade-Insecure-Requests < Accept-Language': 1,
#   'Upgrade-Insecure-Requests < Referer': 1,
#   'Upgrade-Insecure-Requests < User-Agent': 1,
#   'User-Agent < Accept': 1,
#   'User-Agent < Accept-Encoding': 1,
#   'User-Agent < Accept-Language': 1,
#   'User-Agent < Referer': 1},
#  {'Accept-Encoding < Connection': 1,
#   'Accept-Encoding < Host': 1,
#   'Accept-Language < Accept-Encoding': 1,
#   'Accept-Language < Connection': 1,
#   'Accept-Language < Host': 1,
#   'Accept-Language < User-Agent': 1,
#   'Host < Connection': 1,
#   'User-Agent < Accept-Encoding': 1,
#   'User-Agent < Connection': 1,
#   'User-Agent < Host': 1},
#  {'Accept < Accept-Encoding': 1,
#   'Accept < From': 1,
#   'Accept < Host': 1,
#   'Accept < User-Agent': 1,
#   'Accept-Encoding < From': 1,
#   'Accept-Encoding < Host': 1,
#   'Accept-Encoding < User-Agent': 1,
#   'From < Host': 1,
#   'From < User-Agent': 1,
#   'Host < User-Agent': 1,
#   'Pragma < Accept': 1,
#   'Pragma < Accept-Encoding': 1,
#   'Pragma < From': 1,
#   'Pragma < Host': 1,
#   'Pragma < User-Agent': 1},
#  {'Accept-Encoding < Connection': 1,
#   'Accept-Encoding < Host': 1,
#   'Accept-Encoding < User-Agent': 1,
#   'Host < Connection': 1,
#   'User-Agent < Connection': 1,
#   'User-Agent < Host': 1},
#  {'User-Agent < Accept-Encoding': 1},
#  {'Accept < Accept-Encoding': 1,
#   'Accept < From': 1,
#   'Accept < Host': 1,
#   'Accept < User-Agent': 1,
#   'Accept-Encoding < From': 1,
#   'Accept-Encoding < Host': 1,
#   'Accept-Encoding < User-Agent': 1,
#   'From < Host': 1,
#   'From < User-Agent': 1,
#   'Host < User-Agent': 1,
#   'Pragma < Accept': 1,
#   'Pragma < Accept-Encoding': 1,
#   'Pragma < From': 1,
#   'Pragma < Host': 1,
#   'Pragma < User-Agent': 1},
#  {'Host < Cookie': 1, 'User-Agent < Cookie': 1, 'User-Agent < Host': 1},
#  {'Accept < Accept-Encoding': 1,
#   'Accept < From': 1,
#   'Accept < Host': 1,
#   'Accept < User-Agent': 1,
#   'Accept-Encoding < From': 1,
#   'Accept-Encoding < Host': 1,
#   'Accept-Encoding < User-Agent': 1,
#   'From < Host': 1,
#   'From < User-Agent': 1,
#   'Host < User-Agent': 1,
#   'Pragma < Accept': 1,
#   'Pragma < Accept-Encoding': 1,
#   'Pragma < From': 1,
#   'Pragma < Host': 1,
#   'Pragma < User-Agent': 1},
#  {'Accept < Accept-Encoding': 1,
#   'Accept < Accept-Language': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Upgrade-Insecure-Requests < Accept': 1,
#   'Upgrade-Insecure-Requests < Accept-Encoding': 1,
#   'Upgrade-Insecure-Requests < Accept-Language': 1,
#   'Upgrade-Insecure-Requests < User-Agent': 1,
#   'User-Agent < Accept': 1,
#   'User-Agent < Accept-Encoding': 1,
#   'User-Agent < Accept-Language': 1},
#  {'Accept < Accept-Encoding': 1,
#   'Accept < Accept-Language': 1,
#   'Accept < Cookie': 1,
#   'Accept < Referer': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Accept-Encoding < Cookie': 1,
#   'Accept-Language < Cookie': 1,
#   'Referer < Accept-Encoding': 1,
#   'Referer < Accept-Language': 1,
#   'Referer < Cookie': 1,
#   'Upgrade-Insecure-Requests < Accept': 1,
#   'Upgrade-Insecure-Requests < Accept-Encoding': 1,
#   'Upgrade-Insecure-Requests < Accept-Language': 1,
#   'Upgrade-Insecure-Requests < Cookie': 1,
#   'Upgrade-Insecure-Requests < Referer': 1,
#   'Upgrade-Insecure-Requests < User-Agent': 1,
#   'User-Agent < Accept': 1,
#   'User-Agent < Accept-Encoding': 1,
#   'User-Agent < Accept-Language': 1,
#   'User-Agent < Cookie': 1,
#   'User-Agent < Referer': 1},
#  {'Accept < Accept-Encoding': 1,
#   'Accept < Accept-Language': 1,
#   'Accept < Referer': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Referer < Accept-Encoding': 1,
#   'Referer < Accept-Language': 1,
#   'Upgrade-Insecure-Requests < Accept': 1,
#   'Upgrade-Insecure-Requests < Accept-Encoding': 1,
#   'Upgrade-Insecure-Requests < Accept-Language': 1,
#   'Upgrade-Insecure-Requests < Referer': 1,
#   'Upgrade-Insecure-Requests < User-Agent': 1,
#   'User-Agent < Accept': 1,
#   'User-Agent < Accept-Encoding': 1,
#   'User-Agent < Accept-Language': 1,
#   'User-Agent < Referer': 1},
#  {'Accept < Accept-Encoding': 1,
#   'Accept < From': 1,
#   'Accept < Host': 1,
#   'Accept < User-Agent': 1,
#   'Accept-Encoding < From': 1,
#   'Accept-Encoding < Host': 1,
#   'Accept-Encoding < User-Agent': 1,
#   'From < Host': 1,
#   'From < User-Agent': 1,
#   'Host < User-Agent': 1,
#   'Pragma < Accept': 1,
#   'Pragma < Accept-Encoding': 1,
#   'Pragma < From': 1,
#   'Pragma < Host': 1,
#   'Pragma < User-Agent': 1},
#  {'Accept < Accept-Language': 1,
#   'Accept < Connection': 1,
#   'Accept < User-Agent': 1,
#   'Accept-Encoding < Accept': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Accept-Encoding < Connection': 1,
#   'Accept-Encoding < User-Agent': 1,
#   'Accept-Language < Connection': 1,
#   'Accept-Language < User-Agent': 1,
#   'Connection < User-Agent': 1},
#  {'Accept < Accept-Encoding': 1,
#   'Accept < From': 1,
#   'Accept < Host': 1,
#   'Accept < User-Agent': 1,
#   'Accept-Encoding < From': 1,
#   'Accept-Encoding < Host': 1,
#   'Accept-Encoding < User-Agent': 1,
#   'From < Host': 1,
#   'From < User-Agent': 1,
#   'Host < User-Agent': 1,
#   'Pragma < Accept': 1,
#   'Pragma < Accept-Encoding': 1,
#   'Pragma < From': 1,
#   'Pragma < Host': 1,
#   'Pragma < User-Agent': 1},
#  {'Accept-Encoding < Connection': 1,
#   'Accept-Encoding < User-Agent': 1,
#   'Accept-Language < Accept-Encoding': 1,
#   'Accept-Language < Connection': 1,
#   'Accept-Language < User-Agent': 1,
#   'Connection < User-Agent': 1},
#  {'Accept < Accept-Encoding': 1,
#   'Accept < User-Agent': 1,
#   'User-Agent < Accept-Encoding': 1},
#  {'Accept < Accept-Encoding': 1,
#   'Accept < From': 1,
#   'Accept < Host': 1,
#   'Accept < User-Agent': 1,
#   'Accept-Encoding < From': 1,
#   'Accept-Encoding < Host': 1,
#   'Accept-Encoding < User-Agent': 1,
#   'From < Host': 1,
#   'From < User-Agent': 1,
#   'Host < User-Agent': 1,
#   'Pragma < Accept': 1,
#   'Pragma < Accept-Encoding': 1,
#   'Pragma < From': 1,
#   'Pragma < Host': 1,
#   'Pragma < User-Agent': 1},
#  {'User-Agent < Accept-Encoding': 1},
#  {'User-Agent < Accept-Encoding': 1},
#  {'Accept < Accept-Encoding': 1,
#   'Accept < Accept-Language': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'User-Agent < Accept': 1,
#   'User-Agent < Accept-Encoding': 1,
#   'User-Agent < Accept-Language': 1},
#  {'Accept < Accept-Language': 1,
#   'Accept < Connection': 1,
#   'Accept < Cookie': 1,
#   'Accept < User-Agent': 1,
#   'Accept-Encoding < Accept': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Accept-Encoding < Connection': 1,
#   'Accept-Encoding < Cookie': 1,
#   'Accept-Encoding < User-Agent': 1,
#   'Accept-Language < Connection': 1,
#   'Accept-Language < User-Agent': 1,
#   'Connection < User-Agent': 1,
#   'Cookie < Accept-Language': 1,
#   'Cookie < Connection': 1,
#   'Cookie < User-Agent': 1},
#  {'User-Agent < Accept-Encoding': 1},
#  {'Accept < Accept-Encoding': 1,
#   'Accept < Accept-Language': 1,
#   'Accept < Referer': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Referer < Accept-Encoding': 1,
#   'Referer < Accept-Language': 1,
#   'Upgrade-Insecure-Requests < Accept': 1,
#   'Upgrade-Insecure-Requests < Accept-Encoding': 1,
#   'Upgrade-Insecure-Requests < Accept-Language': 1,
#   'Upgrade-Insecure-Requests < Referer': 1,
#   'Upgrade-Insecure-Requests < User-Agent': 1,
#   'User-Agent < Accept': 1,
#   'User-Agent < Accept-Encoding': 1,
#   'User-Agent < Accept-Language': 1,
#   'User-Agent < Referer': 1},
#  {'Accept < Accept-Encoding': 1,
#   'Accept < Accept-Language': 1,
#   'Accept < Dnt': 1,
#   'Accept < Referer': 1,
#   'Accept-Encoding < Dnt': 1,
#   'Accept-Encoding < Referer': 1,
#   'Accept-Language < Accept-Encoding': 1,
#   'Accept-Language < Dnt': 1,
#   'Accept-Language < Referer': 1,
#   'Dnt < Referer': 1,
#   'User-Agent < Accept': 1,
#   'User-Agent < Accept-Encoding': 1,
#   'User-Agent < Accept-Language': 1,
#   'User-Agent < Dnt': 1,
#   'User-Agent < Referer': 1},
#  {'Accept < Accept-Encoding': 1,
#   'Accept < From': 1,
#   'Accept < Host': 1,
#   'Accept < If-Modified-Since': 1,
#   'Accept < User-Agent': 1,
#   'Accept-Encoding < From': 1,
#   'Accept-Encoding < Host': 1,
#   'Accept-Encoding < If-Modified-Since': 1,
#   'Accept-Encoding < User-Agent': 1,
#   'From < Host': 1,
#   'From < If-Modified-Since': 1,
#   'From < User-Agent': 1,
#   'Host < If-Modified-Since': 1,
#   'Host < User-Agent': 1,
#   'If-Modified-Since < User-Agent': 1,
#   'Pragma < Accept': 1,
#   'Pragma < Accept-Encoding': 1,
#   'Pragma < From': 1,
#   'Pragma < Host': 1,
#   'Pragma < If-Modified-Since': 1,
#   'Pragma < User-Agent': 1},
#  {'Accept < Accept-Charset': 1,
#   'Accept-Encoding < Accept': 1,
#   'Accept-Encoding < Accept-Charset': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Accept-Language < Accept': 1,
#   'Accept-Language < Accept-Charset': 1},
#  {'Accept < Accept-Charset': 1,
#   'Accept-Encoding < Accept': 1,
#   'Accept-Encoding < Accept-Charset': 1,
#   'Accept-Encoding < Accept-Language': 1,
#   'Accept-Language < Accept': 1,
#   'Accept-Language < Accept-Charset': 1},
#  {'Accept < Accept-Encoding': 1,
#   'Accept < Accept-Language': 1,
#   'Accept < Connection': 1,
#   'Accept < Dnt': 1,
#   'Accept < Referer': 1,
#   'Accept < Upgrade-Insecure-Requests': 1,
#   'Accept-Encoding < Connection': 1,
#   'Accept-Encoding < Dnt': 1,
#   'Accept-Encoding < Referer': 1,
#   'Accept-Encoding < Upgrade-Insecure-Requests': 1,
#   'Accept-Language < Accept-Encoding': 1,
#   'Accept-Language < Connection': 1,
#   'Accept-Language < Dnt': 1,
#   'Accept-Language < Referer': 1,
#   'Accept-Language < Upgrade-Insecure-Requests': 1,
#   'Connection < Dnt': 1,
#   'Connection < Upgrade-Insecure-Requests': 1,
#   'Referer < Connection': 1,
#   'Referer < Dnt': 1,
#   'Referer < Upgrade-Insecure-Requests': 1,
#   'Upgrade-Insecure-Requests < Dnt': 1},
#  {'Accept-Encoding < User-Agent': 1,
#   'Connection < Accept-Encoding': 1,
#   'Connection < User-Agent': 1},
#  {'Accept-Encoding < User-Agent': 1,
#   'Connection < Accept-Encoding': 1,
#   'Connection < User-Agent': 1},
#  {'Accept-Encoding < User-Agent': 1,
#   'Connection < Accept-Encoding': 1,
#   'Connection < User-Agent': 1},
#  {'Accept-Encoding < User-Agent': 1,
#   'Connection < Accept-Encoding': 1,
#   'Connection < User-Agent': 1},
#  ...]

# %%
dummy_vectorizer = sklearn.feature_extraction.DictVectorizer(sparse=True, dtype=float)
sparse_dummy = dummy_vectorizer.fit_transform(pairs_dict_list).astype(np.int8)
print(type(sparse_dummy))
print('Sparse dummy shape: \n{0}'.format(sparse_dummy.shape))
print('User Agent shape: \n{0}'.format(main_top_100.User_Agent.shape))
# Out:
# <class 'scipy.sparse.csr.csr_matrix'>
# Sparse dummy shape:
# (181851, 1042)
# User Agent shape:
# (181851,)

# %% [markdown]
# ### Добавим значения ключей в модель

# %% [markdown]
# **Согласно README удалим неинформативные ключи**

# %%
exception_keys_set = {
    'User-Agent', 'Referer', 'Accept-Language', 'Host', 'X-Host','X-Forwarded-For',
    'Forwarded-For' ,'X-Network-Type','Cookie','X-Wap-Profile','X-Gateway','Ua-Cpu',
    'Rvbd-Csh','Dris-Orig-Src','X-Proxy-Id','Rvbd-Ssh','X-Requested-With'}

# %%
trimmed_values_data = list(values_data)

for row_index in tqdm(range(len(trimmed_values_data))):
    for key in exception_keys_set:
        trimmed_values_data[row_index].pop(key, -1)
# Out:
# 100%|██████████| 289269/289269 [00:01<00:00, 193902.11it/s]

# %%
len(values_data)
# Out:
# 289269

# %%
values_df = pd.DataFrame(trimmed_values_data)
values_df.head()
# Out:
#                                               Accept Accept-Charset  \
# 0  text/html,application/xhtml+xml,application/xm...            NaN
# 1                                                */*            NaN
# 2  text/html,application/xhtml+xml,application/xm...            NaN
# 3  text/html,application/xhtml+xml,application/xm...            NaN
# 4                                                */*            NaN
#
#        Accept-Encoding Authorization Cache-Control Cdn-Src-Ip Charset  \
# 0  gzip, deflate, sdch           NaN           NaN        NaN     NaN
# 1        gzip, deflate           NaN      no-cache        NaN     NaN
# 2  gzip, deflate, sdch           NaN           NaN        NaN     NaN
# 3        gzip, deflate           NaN           NaN        NaN     NaN
# 4        gzip, deflate           NaN           NaN        NaN     NaN
#
#   Chrome-Proxy Chrome-Proxy-Accept-Transform Client-Ip Clientip  Cmd  \
# 0          NaN                           NaN       NaN      NaN  NaN
# 1          NaN                           NaN       NaN      NaN  NaN
# 2          NaN                           NaN       NaN      NaN  NaN
# 3          NaN                           NaN       NaN      NaN  NaN
# 4          NaN                           NaN       NaN      NaN  NaN
#
#    Connection Content-Length Content-Range Content-Type Cookie2 Date  \
# 0         NaN            NaN           NaN          NaN     NaN  NaN
# 1  Keep-Alive            NaN           NaN          NaN     NaN  NaN
# 2  keep-alive            NaN           NaN          NaN     NaN  NaN
# 3  keep-alive            NaN           NaN          NaN     NaN  NaN
# 4       close            NaN           NaN          NaN     NaN  NaN
#
#   Device-Stock-Ua  Dnt Drm-Version F5-User-Ip Forwarded  \
# 0             NaN  NaN         NaN        NaN       NaN
# 1             NaN  NaN         NaN        NaN       NaN
# 2             NaN  NaN         NaN        NaN       NaN
# 3             NaN  NaN         NaN        NaN       NaN
# 4             NaN  NaN         NaN        NaN       NaN
#
#                        From Giga-Transport Http-Version Http2-Settings Https  \
# 0                       NaN            NaN          NaN            NaN   NaN
# 1  bingbot(at)microsoft.com            NaN          NaN            NaN   NaN
# 2                       NaN            NaN          NaN            NaN   NaN
# 3                       NaN            NaN          NaN            NaN   NaN
# 4                       NaN            NaN          NaN            NaN   NaN
#
#   If-Modified-Since If-None-Match Inter-Pro-Client Keep-Alive O2gw-Id Origin  \
# 0               NaN           NaN              NaN        NaN     NaN    NaN
# 1               NaN           NaN              NaN        NaN     NaN    NaN
# 2               NaN           NaN              NaN        NaN     NaN    NaN
# 3               NaN           NaN              NaN        NaN     NaN    NaN
# 4               NaN           NaN              NaN        NaN     NaN    NaN
#
#   Oxpry-Connection Ping-From Ping-To    Pragma Prefer Proxy-Authorization  \
# 0              NaN       NaN     NaN       NaN    NaN                 NaN
# 1              NaN       NaN     NaN  no-cache    NaN                 NaN
# 2              NaN       NaN     NaN       NaN    NaN                 NaN
# 3              NaN       NaN     NaN       NaN    NaN                 NaN
# 4              NaN       NaN     NaN  no-cache    NaN                 NaN
#
#   Proxy-Connection Purpose Q-Refer Q-Ua Range Refresh-Cache  \
# 0              NaN     NaN     NaN  NaN   NaN           NaN
# 1              NaN     NaN     NaN  NaN   NaN           NaN
# 2              NaN     NaN     NaN  NaN   NaN           NaN
# 3              NaN     NaN     NaN  NaN   NaN           NaN
# 4              NaN     NaN     NaN  NaN   NaN           NaN
#
#   Rmch-Securitycookie Save-Data Scheme Surrogate-Capability   Te Upgrade  \
# 0                 NaN       NaN    NaN                  NaN  NaN     NaN
# 1                 NaN       NaN    NaN                  NaN  NaN     NaN
# 2                 NaN       NaN    NaN                  NaN  NaN     NaN
# 3                 NaN       NaN    NaN                  NaN  NaN     NaN
# 4                 NaN       NaN    NaN                  NaN  NaN     NaN
#
#   Upgrade-Insecure-Requests Useragent Version  Via Wap-Connection  \
# 0                         1       NaN     NaN  NaN            NaN
# 1                       NaN       NaN     NaN  NaN            NaN
# 2                         1       NaN     NaN  NaN            NaN
# 3                         1       NaN     NaN  NaN            NaN
# 4                       NaN       NaN     NaN  NaN            NaN
#
#   Wapconnection Wshost Wsip X-------------- X-Accept-Encoding-Wn-Proxy-2  \
# 0           NaN    NaN  NaN             NaN                          NaN
# 1           NaN    NaN  NaN             NaN                          NaN
# 2           NaN    NaN  NaN             NaN                          NaN
# 3           NaN    NaN  NaN             NaN                          NaN
# 4           NaN    NaN  NaN             NaN                          NaN
#
#   X-Agent-Client-Id X-Agent-Session-Id X-Att-Deviceid X-Authenticated-User  \
# 0               NaN                NaN            NaN                  NaN
# 1               NaN                NaN            NaN                  NaN
# 2               NaN                NaN            NaN                  NaN
# 3               NaN                NaN            NaN                  NaN
# 4               NaN                NaN            NaN                  NaN
#
#   X-B3-Flags X-B3-Parentspanid X-B3-Sampled X-B3-Spanid X-B3-Traceid  \
# 0        NaN               NaN          NaN         NaN          NaN
# 1        NaN               NaN          NaN         NaN          NaN
# 2        NaN               NaN          NaN         NaN          NaN
# 3        NaN               NaN          NaN         NaN          NaN
# 4        NaN               NaN          NaN         NaN          NaN
#
#   X-Bluecoat-Via X-Busid X-Categories X-Chrome-Connected X-Chrome-Uma-Enabled  \
# 0            NaN     NaN          NaN                NaN                  NaN
# 1            NaN     NaN          NaN                NaN                  NaN
# 2            NaN     NaN          NaN                NaN                  NaN
# 3            NaN     NaN          NaN                NaN                  NaN
# 4            NaN     NaN          NaN                NaN                  NaN
#
#   X-Citrio-Timestamp X-Client-Data X-Cloud-Trace-Context X-Compress  \
# 0                NaN           NaN                   NaN        NaN
# 1                NaN           NaN                   NaN        NaN
# 2                NaN           NaN                   NaN        NaN
# 3                NaN           NaN                   NaN        NaN
# 4                NaN           NaN                   NaN        NaN
#
#   X-Content-Check X-Content-Opt X-D-Forwarder X-Ebo-Ua X-Fb-Http-Engine  \
# 0             NaN           NaN           NaN      NaN              NaN
# 1             NaN           NaN           NaN      NaN              NaN
# 2             NaN           NaN           NaN      NaN              NaN
# 3             NaN           NaN           NaN      NaN              NaN
# 4             NaN           NaN           NaN      NaN              NaN
#
#   X-Fb-Net-Hni X-Fb-Sim-Hni X-Featureversion X-Firephp X-Firephp-Version  \
# 0          NaN          NaN              NaN       NaN               NaN
# 1          NaN          NaN              NaN       NaN               NaN
# 2          NaN          NaN              NaN       NaN               NaN
# 3          NaN          NaN              NaN       NaN               NaN
# 4          NaN          NaN              NaN       NaN               NaN
#
#   X-Forwarded-Proto X-Fuck X-Getzip X-Gfe-Ssl X-Gfe-Tls-Channelid  \
# 0               NaN    NaN      NaN       NaN                 NaN
# 1               NaN    NaN      NaN       NaN                 NaN
# 2               NaN    NaN      NaN       NaN                 NaN
# 3               NaN    NaN      NaN       NaN                 NaN
# 4               NaN    NaN      NaN       NaN                 NaN
#
#   X-Icap-Http-Stream X-Icm X-Imforwards X-Iws-Via X-Lb-Local  \
# 0                NaN   NaN          NaN       NaN        NaN
# 1                NaN   NaN          NaN       NaN        NaN
# 2                NaN   NaN          NaN       NaN        NaN
# 3                NaN   NaN          NaN       NaN        NaN
# 4                NaN   NaN          NaN       NaN        NaN
#
#   X-Liveinternetapplications X-Loop-Control X-Mcproxyfilter X-Mfe-Response  \
# 0                        NaN            NaN             NaN            NaN
# 1                        NaN            NaN             NaN            NaN
# 2                        NaN            NaN             NaN            NaN
# 3                        NaN            NaN             NaN            NaN
# 4                        NaN            NaN             NaN            NaN
#
#   X-Miorigin X-Moz X-Ms-Cookieuri-Requested X-Msisdn X-Mwg-Via X-Newrelic-Id  \
# 0        NaN   NaN                      NaN      NaN       NaN           NaN
# 1        NaN   NaN                      NaN      NaN       NaN           NaN
# 2        NaN   NaN                      NaN      NaN       NaN           NaN
# 3        NaN   NaN                      NaN      NaN       NaN           NaN
# 4        NaN   NaN                      NaN      NaN       NaN           NaN
#
#   X-Newrelic-Transaction X-Nokia-Bearer X-Nokia-Gateway-Id  \
# 0                    NaN            NaN                NaN
# 1                    NaN            NaN                NaN
# 2                    NaN            NaN                NaN
# 3                    NaN            NaN                NaN
# 4                    NaN            NaN                NaN
#
#   X-Nokia-Maxdownlinkbitrate X-Nokia-Maxuplinkbitrate  \
# 0                        NaN                      NaN
# 1                        NaN                      NaN
# 2                        NaN                      NaN
# 3                        NaN                      NaN
# 4                        NaN                      NaN
#
#   X-Nokia-Musicshop-Bearer X-Nokia-Musicshop-Version X-Ob  \
# 0                      NaN                       NaN  NaN
# 1                      NaN                       NaN  NaN
# 2                      NaN                       NaN  NaN
# 3                      NaN                       NaN  NaN
# 4                      NaN                       NaN  NaN
#
#   X-Office-Major-Version X-Onv-Icap X-Openfrequencylimit X-Openshield  \
# 0                    NaN        NaN                  NaN          NaN
# 1                    NaN        NaN                  NaN          NaN
# 2                    NaN        NaN                  NaN          NaN
# 3                    NaN        NaN                  NaN          NaN
# 4                    NaN        NaN                  NaN          NaN
#
#   X-Opera-Id X-Opera-Info X-Operamini-Fb X-Operamini-Features  \
# 0        NaN          NaN            NaN                  NaN
# 1        NaN          NaN            NaN                  NaN
# 2        NaN          NaN            NaN                  NaN
# 3        NaN          NaN            NaN                  NaN
# 4        NaN          NaN            NaN                  NaN
#
#   X-Operamini-Phone X-Operamini-Phone-Ua X-Operamini-Route X-Org-Request  \
# 0               NaN                  NaN               NaN           NaN
# 1               NaN                  NaN               NaN           NaN
# 2               NaN                  NaN               NaN           NaN
# 3               NaN                  NaN               NaN           NaN
# 4               NaN                  NaN               NaN           NaN
#
#   X-Original-Url X-P2p-Peerdist X-P2p-Peerdistex X-Pocket-Parser  \
# 0            NaN            NaN              NaN             NaN
# 1            NaN            NaN              NaN             NaN
# 2            NaN            NaN              NaN             NaN
# 3            NaN            NaN              NaN             NaN
# 4            NaN            NaN              NaN             NaN
#
#   X-Ps3-Browser X-Psa-Client-Features X-Psa-Client-Options X-Psp-Browser  \
# 0           NaN                   NaN                  NaN           NaN
# 1           NaN                   NaN                  NaN           NaN
# 2           NaN                   NaN                  NaN           NaN
# 3           NaN                   NaN                  NaN           NaN
# 4           NaN                   NaN                  NaN           NaN
#
#   X-Psp-Productcode X-Puffin-Ua X-Purpose X-Rbt-Optimized-By X-Real-Ip  \
# 0               NaN         NaN       NaN                NaN       NaN
# 1               NaN         NaN       NaN                NaN       NaN
# 2               NaN         NaN       NaN                NaN       NaN
# 3               NaN         NaN       NaN                NaN       NaN
# 4               NaN         NaN       NaN                NaN       NaN
#
#   X-Requestfrom X-Server-Ip X-Time X-Turbo-Compression X-Turbo-Id  \
# 0           NaN         NaN    NaN                 NaN        NaN
# 1           NaN         NaN    NaN                 NaN        NaN
# 2           NaN         NaN    NaN                 NaN        NaN
# 3           NaN         NaN    NaN                 NaN        NaN
# 4           NaN         NaN    NaN                 NaN        NaN
#
#   X-Ucbrowser-Device X-Ucbrowser-Device-Ua X-Ucbrowser-Ua X-Up-Vfza-Id X-User  \
# 0                NaN                   NaN            NaN          NaN    NaN
# 1                NaN                   NaN            NaN          NaN    NaN
# 2                NaN                   NaN            NaN          NaN    NaN
# 3                NaN                   NaN            NaN          NaN    NaN
# 4                NaN                   NaN            NaN          NaN    NaN
#
#   X-Vermeer-Content-Type X-Wap-Client-Ip X-Wap-Profile-Diff  \
# 0                    NaN             NaN                NaN
# 1                    NaN             NaN                NaN
# 2                    NaN             NaN                NaN
# 3                    NaN             NaN                NaN
# 4                    NaN             NaN                NaN
#
#   X-Wap-Proxy-Cookie X-Wapipaddr X-Wf-Max-Combined-Size X-Wisp  \
# 0                NaN         NaN                    NaN    NaN
# 1                NaN         NaN                    NaN    NaN
# 2                NaN         NaN                    NaN    NaN
# 3                NaN         NaN                    NaN    NaN
# 4                NaN         NaN                    NaN    NaN
#
#   X-Xorwarded-For X-Xuthenticated-User X-Yandex-Turbo X-Youtube-Edu-Filter  \
# 0             NaN                  NaN            NaN                  NaN
# 1             NaN                  NaN            NaN                  NaN
# 2             NaN                  NaN            NaN                  NaN
# 3             NaN                  NaN            NaN                  NaN
# 4             NaN                  NaN            NaN                  NaN
#
#     X3 Xroxy-Connection
# 0  NaN              NaN
# 1  NaN              NaN
# 2  NaN              NaN
# 3  NaN              NaN
# 4  NaN              NaN

# %%
print(values_df.shape)
for column in values_df.columns:
    print(column, values_df[column].unique().shape, values_df[column].dropna().shape)
# Out:
# (289269, 166)
# Accept (255,) (275910,)
# Accept-Charset (66,) (21277,)
# Accept-Encoding (43,) (271181,)
# Authorization (3,) (9,)
# Cache-Control (76,) (27250,)
# Cdn-Src-Ip (2,) (1,)
# Charset (2,) (3,)
# Chrome-Proxy (10,) (12,)
# Chrome-Proxy-Accept-Transform (2,) (4,)
# Client-Ip (8,) (9,)
# Clientip (724,) (856,)
# Cmd (43,) (42,)
# Connection (15,) (233710,)
# Content-Length (638,) (1587,)
# Content-Range (2,) (12,)
# Content-Type (15,) (2702,)
# Cookie2 (4,) (22,)
# Date (9,) (8,)
# Device-Stock-Ua (579,) (1208,)
# Dnt (3,) (16536,)
# Drm-Version (4,) (9,)
# F5-User-Ip (14,) (15,)
# Forwarded (6248,) (7682,)
# From (18,) (37298,)
# Giga-Transport (50,) (49,)
# Http-Version (2,) (2,)
# Http2-Settings (2,) (2,)
# Https (2,) (19,)
# If-Modified-Since (10880,) (11255,)
# If-None-Match (4,) (21,)
# Inter-Pro-Client (3,) (8,)
# Keep-Alive (6,) (836,)
# O2gw-Id (4,) (3,)
# Origin (8,) (176,)
# Oxpry-Connection (2,) (3,)
# Ping-From (45,) (46,)
# Ping-To (37,) (46,)
# Pragma (2,) (22310,)
# Prefer (2,) (50,)
# Proxy-Authorization (222,) (336,)
# Proxy-Connection (5,) (346,)
# Purpose (2,) (1,)
# Q-Refer (2,) (1,)
# Q-Ua (3,) (3,)
# Range (10,) (483,)
# Refresh-Cache (2,) (2,)
# Rmch-Securitycookie (2,) (1,)
# Save-Data (3,) (8824,)
# Scheme (2,) (4849,)
# Surrogate-Capability (74,) (317,)
# Te (4,) (892,)
# Upgrade (3,) (2,)
# Upgrade-Insecure-Requests (2,) (111716,)
# Useragent (2,) (1,)
# Version (2,) (38,)
# Via (1590,) (11229,)
# Wap-Connection (2,) (13,)
# Wapconnection (2,) (4,)
# Wshost (16,) (15,)
# Wsip (2,) (15,)
# X-------------- (3,) (2,)
# X-Accept-Encoding-Wn-Proxy-2 (2,) (2,)
# X-Agent-Client-Id (2,) (1,)
# X-Agent-Session-Id (2,) (1,)
# X-Att-Deviceid (4,) (12,)
# X-Authenticated-User (3,) (2,)
# X-B3-Flags (2,) (14,)
# X-B3-Parentspanid (15,) (14,)
# X-B3-Sampled (2,) (14,)
# X-B3-Spanid (15,) (14,)
# X-B3-Traceid (15,) (14,)
# X-Bluecoat-Via (58,) (164,)
# X-Busid (2,) (1,)
# X-Categories (2,) (7,)
# X-Chrome-Connected (6,) (5,)
# X-Chrome-Uma-Enabled (2,) (13,)
# X-Citrio-Timestamp (5,) (4,)
# X-Client-Data (53,) (59,)
# X-Cloud-Trace-Context (16,) (15,)
# X-Compress (5,) (1337,)
# X-Content-Check (2,) (1,)
# X-Content-Opt (4,) (104,)
# X-D-Forwarder (2,) (1,)
# X-Ebo-Ua (58,) (69,)
# X-Fb-Http-Engine (2,) (2,)
# X-Fb-Net-Hni (2,) (1,)
# X-Fb-Sim-Hni (3,) (2,)
# X-Featureversion (2,) (5,)
# X-Firephp (2,) (1,)
# X-Firephp-Version (2,) (1,)
# X-Forwarded-Proto (2,) (1395,)
# X-Fuck (2,) (1,)
# X-Getzip (2,) (283,)
# X-Gfe-Ssl (2,) (2,)
# X-Gfe-Tls-Channelid (2,) (2,)
# X-Icap-Http-Stream (2,) (1,)
# X-Icm (2,) (2,)
# X-Imforwards (2,) (66,)
# X-Iws-Via (5,) (4,)
# X-Lb-Local (3,) (47,)
# X-Liveinternetapplications (2,) (16,)
# X-Loop-Control (3,) (2,)
# X-Mcproxyfilter (3,) (2,)
# X-Mfe-Response (2,) (1,)
# X-Miorigin (4,) (60,)
# X-Moz (2,) (1982,)
# X-Ms-Cookieuri-Requested (2,) (5,)
# X-Msisdn (6,) (10,)
# X-Mwg-Via (3,) (2,)
# X-Newrelic-Id (3,) (164,)
# X-Newrelic-Transaction (164,) (164,)
# X-Nokia-Bearer (3,) (11,)
# X-Nokia-Gateway-Id (2,) (11,)
# X-Nokia-Maxdownlinkbitrate (2,) (11,)
# X-Nokia-Maxuplinkbitrate (2,) (11,)
# X-Nokia-Musicshop-Bearer (4,) (24,)
# X-Nokia-Musicshop-Version (7,) (24,)
# X-Ob (2,) (5,)
# X-Office-Major-Version (2,) (5,)
# X-Onv-Icap (2,) (4,)
# X-Openfrequencylimit (2,) (1,)
# X-Openshield (2,) (1,)
# X-Opera-Id (7,) (8,)
# X-Opera-Info (45,) (46,)
# X-Operamini-Fb (4,) (5,)
# X-Operamini-Features (16,) (1317,)
# X-Operamini-Phone (37,) (1317,)
# X-Operamini-Phone-Ua (575,) (1309,)
# X-Operamini-Route (2,) (259,)
# X-Org-Request (2,) (1,)
# X-Original-Url (3,) (2,)
# X-P2p-Peerdist (3,) (33,)
# X-P2p-Peerdistex (2,) (8,)
# X-Pocket-Parser (2,) (7,)
# X-Ps3-Browser (2,) (3,)
# X-Psa-Client-Features (3,) (4,)
# X-Psa-Client-Options (2,) (2,)
# X-Psp-Browser (3,) (16,)
# X-Psp-Productcode (3,) (16,)
# X-Puffin-Ua (3,) (3,)
# X-Purpose (2,) (52,)
# X-Rbt-Optimized-By (2,) (2,)
# X-Real-Ip (12,) (26,)
# X-Requestfrom (2,) (2,)
# X-Server-Ip (2,) (1,)
# X-Time (2,) (1,)
# X-Turbo-Compression (2,) (332,)
# X-Turbo-Id (2,) (4,)
# X-Ucbrowser-Device (16,) (29,)
# X-Ucbrowser-Device-Ua (46,) (85,)
# X-Ucbrowser-Ua (718,) (942,)
# X-Up-Vfza-Id (2,) (1,)
# X-User (2,) (1,)
# X-Vermeer-Content-Type (2,) (4,)
# X-Wap-Client-Ip (2,) (1,)
# X-Wap-Profile-Diff (12,) (128,)
# X-Wap-Proxy-Cookie (3,) (27,)
# X-Wapipaddr (5,) (4,)
# X-Wf-Max-Combined-Size (2,) (1,)
# X-Wisp (2,) (1,)
# X-Xorwarded-For (3,) (2,)
# X-Xuthenticated-User (2,) (1,)
# X-Yandex-Turbo (3,) (1434,)
# X-Youtube-Edu-Filter (2,) (3,)
# X3 (2,) (1,)
# Xroxy-Connection (3,) (14,)

# %% [markdown]
# Применим очень тупой отбор признаков:
# - если определенный ключ появляется ну очень редко(например менее чем в 0.1% хэдэров, то мы считаем его неинформативным)
# - если у определенного ключа почти все значения различны(например если отношение общего значений к числу уникальных очень мало(например меньше 2)
# - если слишком много уникальных значений выключим, фича толская и ухудшает предстказание (больше 1000)

# %%
print(values_df.shape)
important_keys = []
for column in values_df.columns:
    not_null_count = values_df[column].dropna().shape[0]
    if not_null_count  >= values_df.shape[0] * 0.001:
        uniq_count = values_df[column].unique().shape[0]
        if not_null_count / uniq_count >= 2:
            if uniq_count < 1000:
                print(column, uniq_count, not_null_count)
                important_keys.append(column)
' '.join(important_keys)
# Out:
# (289269, 28)
# Accept 255 275910
# Accept-Charset 66 21277
# Accept-Encoding 43 271181
# Cache-Control 76 27250
# Connection 15 233710
# Content-Length 638 1587
# Content-Type 15 2702
# Device-Stock-Ua 579 1208
# Dnt 3 16536
# From 18 37298
# Keep-Alive 6 836
# Pragma 2 22310
# Proxy-Connection 5 346
# Range 10 483
# Save-Data 3 8824
# Scheme 2 4849
# Surrogate-Capability 74 317
# Te 4 892
# Upgrade-Insecure-Requests 2 111716
# X-Compress 5 1337
# X-Forwarded-Proto 2 1395
# X-Moz 2 1982
# X-Operamini-Features 16 1317
# X-Operamini-Phone 37 1317
# X-Operamini-Phone-Ua 575 1309
# X-Turbo-Compression 2 332
# X-Yandex-Turbo 3 1434
# 'Accept Accept-Charset Accept-Encoding Cache-Control Connection Content-Length Content-Type Device-Stock-Ua Dnt From Keep-Alive Pragma Proxy-Connection Range Save-Data Scheme Surrogate-Capability Te Upgrade-Insecure-Requests X-Compress X-Forwarded-Proto X-Moz X-Operamini-Features X-Operamini-Phone X-Operamini-Phone-Ua X-Turbo-Compression X-Yandex-Turbo'

# %%
#important_keys = []
#important_keys = ['Accept', 'Accept-Charset', 'Accept-Encoding']
important_keys = ['Accept', 'Accept-Encoding', ]

# %%
values_df = values_df[important_keys]
values_df.head()
# Out:
#                                               Accept Accept-Charset  \
# 0  text/html,application/xhtml+xml,application/xm...            NaN
# 1                                                */*            NaN
# 2  text/html,application/xhtml+xml,application/xm...            NaN
# 3  text/html,application/xhtml+xml,application/xm...            NaN
# 4                                                */*            NaN
#
#        Accept-Encoding Cache-Control  Connection Content-Length Content-Type  \
# 0  gzip, deflate, sdch           NaN         NaN            NaN          NaN
# 1        gzip, deflate      no-cache  Keep-Alive            NaN          NaN
# 2  gzip, deflate, sdch           NaN  keep-alive            NaN          NaN
# 3        gzip, deflate           NaN  keep-alive            NaN          NaN
# 4        gzip, deflate           NaN       close            NaN          NaN
#
#   Device-Stock-Ua  Dnt                      From Keep-Alive    Pragma  \
# 0             NaN  NaN                       NaN        NaN       NaN
# 1             NaN  NaN  bingbot(at)microsoft.com        NaN  no-cache
# 2             NaN  NaN                       NaN        NaN       NaN
# 3             NaN  NaN                       NaN        NaN       NaN
# 4             NaN  NaN                       NaN        NaN  no-cache
#
#   Proxy-Connection Range Save-Data Scheme Surrogate-Capability   Te  \
# 0              NaN   NaN       NaN    NaN                  NaN  NaN
# 1              NaN   NaN       NaN    NaN                  NaN  NaN
# 2              NaN   NaN       NaN    NaN                  NaN  NaN
# 3              NaN   NaN       NaN    NaN                  NaN  NaN
# 4              NaN   NaN       NaN    NaN                  NaN  NaN
#
#   Upgrade-Insecure-Requests  Via X-Compress X-Forwarded-Proto X-Moz  \
# 0                         1  NaN        NaN               NaN   NaN
# 1                       NaN  NaN        NaN               NaN   NaN
# 2                         1  NaN        NaN               NaN   NaN
# 3                         1  NaN        NaN               NaN   NaN
# 4                       NaN  NaN        NaN               NaN   NaN
#
#   X-Operamini-Features X-Operamini-Phone X-Operamini-Phone-Ua  \
# 0                  NaN               NaN                  NaN
# 1                  NaN               NaN                  NaN
# 2                  NaN               NaN                  NaN
# 3                  NaN               NaN                  NaN
# 4                  NaN               NaN                  NaN
#
#   X-Turbo-Compression X-Yandex-Turbo
# 0                 NaN            NaN
# 1                 NaN            NaN
# 2                 NaN            NaN
# 3                 NaN            NaN
# 4                 NaN            NaN

# %%
len(trimmed_values_data)
# Out:
# 100%|██████████| 289269/289269 [00:01<00:00, 223867.83it/s]

# %%
values_data_top_100 = []

for row_index in tqdm(range(len(trimmed_values_data))):
    tmp_row = {}
    for key in trimmed_values_data[row_index].keys():
        if key in important_keys:
            tmp_row[key] = trimmed_values_data[row_index][key]
    if row_index in main_top_100.index:
        values_data_top_100.append(tmp_row)
# Out:
# 100%|██████████| 289269/289269 [00:00<00:00, 412461.02it/s]

# %%
values_data_top_100
#len(main_top_100.index)
#main_top_100.index.shape
# Out:
# [{},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {'Accept-Charset': 'utf-8, *;q=0.5'},
#  {'Accept-Charset': 'utf-8, *;q=0.5'},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {'Accept-Charset': 'utf-8, *;q=0.5'},
#  {},
#  {'Accept-Charset': 'utf-8, *;q=0.5'},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {'Accept-Charset': 'utf-8,iso-8859-1;q=0.7,*;q=0.6'},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {'Accept-Charset': 'utf-8,iso-8859-1;q=0.7,*;q=0.6'},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {'Accept-Charset': 'utf-8,iso-8859-1;q=0.7,*;q=0.6'},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {'Accept-Charset': 'UTF-8'},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {'Accept-Charset': 'utf-8,iso-8859-1;q=0.7,*;q=0.6'},
#  {},
#  {},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {'Accept-Charset': 'utf-8,iso-8859-1;q=0.7,*;q=0.6'},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {},
#  {'Accept-Charset': 'utf-8,iso-8859-1;q=0.7,*;q=0.6'},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {'Accept-Charset': 'UTF-8'},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {'Accept-Charset': 'utf-8,iso-8859-1;q=0.7,*;q=0.6'},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {'Accept-Charset': 'utf-8,iso-8859-1;q=0.7,*;q=0.6'},
#  {},
#  {'Accept-Charset': 'utf-8,windows-1251;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {'Accept-Charset': 'utf-8,iso-8859-1;q=0.7,*;q=0.6'},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {'Accept-Charset': 'windows-1251,utf-8;q=0.7,*;q=0.7'},
#  {},
#  {},
#  {},
#  {},
#  {},
#  ...]

# %%
#sparse_dummy_values = pd.get_dummies(values_df).to_sparse(a)
values_vectorizer = sklearn.feature_extraction.DictVectorizer(sparse=True, dtype=float)
sparse_dummy_values = orders_vectorizer.fit_transform(values_data_top_100).astype(np.int8)

# %%
sparse_dummy_values.shape
# Out:
# (181851, 70)

# %%
sparse_dummy.shape
# Out:
# (181851, 1042)

# %% [markdown]
# - sparse_dummy - наивные начальные данные без TF-IDF
# - sparse_dummy_values - значения

# %% [markdown]
# ### Сконкатенируем все фичи

# %%
from scipy.sparse import hstack
full_sparce_dummy = hstack((sparse_dummy, sparse_dummy_values))

# %% [markdown]
# ### Попробуем снова классифицировать

# %%
from sklearn.model_selection import GridSearchCV, cross_val_predict, cross_val_score, train_test_split, KFold
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score, roc_curve, f1_score, make_scorer
from sklearn.multiclass import OneVsRestClassifier
from sklearn import preprocessing

lb = preprocessing.LabelBinarizer()
lb.fit(top_ua)
y = lb.transform(main_top_100.User_Agent)

# %%
X_train, X_test, y_train, y_test = train_test_split(full_sparce_dummy, y, test_size=0.33, random_state=42)

# %%
# %%time
clf = OneVsRestClassifier(LogisticRegression(random_state=42))
clf.fit(X_train, y_train)
answer = clf.predict(X_test)
# Out:
# CPU times: user 2min 12s, sys: 60 ms, total: 2min 12s
# Wall time: 2min 12s

# %%
from sklearn.metrics import accuracy_score

print("Accuracy score {0}".format(accuracy_score(y_true=y_test, y_pred=answer)))
print("F1 score {0}".format(f1_score(y_true=y_test, y_pred=answer, average='samples')))
# Out:
# Accuracy score 0.5835096898901868
# F1 score 0.5836985441557936

# %%
# %%time

params = {'estimator__C': np.logspace(-5, 5, 11)}

model = OneVsRestClassifier(LogisticRegression(random_state=42))
gs = GridSearchCV(model, params, n_jobs=-1, scoring='f1_samples', cv=5)
gs.fit(sparse_dummy, y)
# Out:
# CPU times: user 6min 56s, sys: 1.58 s, total: 6min 58s
# Wall time: 2h 49s

# %%
pd.DataFrame(gs.cv_results_)[['mean_test_score', 'params']].sort_values('mean_test_score', ascending=False)
# Out:
#     mean_test_score                      params
# 7          0.549495     {'estimator__C': 100.0}
# 10         0.549242  {'estimator__C': 100000.0}
# 8          0.549190    {'estimator__C': 1000.0}
# 9          0.549149   {'estimator__C': 10000.0}
# 6          0.548842      {'estimator__C': 10.0}
# ..              ...                         ...
# 4          0.534970       {'estimator__C': 0.1}
# 3          0.500140      {'estimator__C': 0.01}
# 2          0.332464     {'estimator__C': 0.001}
# 1          0.215088    {'estimator__C': 0.0001}
# 0          0.000000     {'estimator__C': 1e-05}
#
# [11 rows x 2 columns]

# %%
full_sparce_dummy.shape
# Out:
# (181851, 9906)

# %%
top_ua

# %%
clf = OneVsRestClassifier(LogisticRegression(random_state=42, C=100)) #C=100000
# %time y_hat_dummy = cross_val_predict(clf, full_sparce_dummy, y, method='predict_proba')
# Out:
# CPU times: user 1h 5min 58s, sys: 1min 41s, total: 1h 7min 39s
# Wall time: 25min 33s

# %% [markdown]
# ### Собственный скоринг

# %%
# %load_ext autoreload
# %reload_ext autoreload

#from thresholdPredictions import thresholded_score

def thresholded_score(alpha, y, y_cross_val):
    """
    :param alpha: Threshold
    :param y: y sample
    :param y_cross_val: y from cross_val_predict
    :return: true if at least one predicted User Agent equal true User Agent
    """
    correct_answers = 0
    answers_count = []
    for i, y_labels in enumerate(y):
        for j, y_answ in enumerate(y_labels):
            answers_count.append(np.count_nonzero(y_cross_val[i] > alpha))
            if (y_answ == 1) and (y_cross_val[i][j] > alpha):
                correct_answers += 1

    return correct_answers / len(y), np.average(answers_count)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from thresholdPredictions import ThresholdPredictions

pred = ThresholdPredictions(user_agent_list=top_ua)

# %%
scores = np.array([thresholded_score(alpha, y, y_hat_dummy) for alpha in [0.001, 0.1]], np.dtype('float,float'))

# %%
#scores['f0']
#scores['f1']
#np.max(scores['f0'])
scores[scores['f1'] < 8]['f0']
# Out:
# array([ 0.97888381,  0.76525287])

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (20, 5)

from matplotlib.pyplot import *

# %%
alphas = np.linspace(0.0, 0.501, 1000)
scores = np.array([thresholded_score(alpha, y, y_hat_dummy) for alpha in alphas], np.dtype('float,float'))

# %%
fixed_count = 1.9

s_tp = scores['f0']
s_lc = scores['f1']
s_t = np.full(len(scores['f0']), fixed_count)

plot(alphas, s_tp, '-b', label='Score true positive');
plot(alphas, s_lc, '-r', label='Score label count');
plot(alphas, s_t, '-g', label='Label count limit');

# %% [markdown]
# ### Скопируем значение первого элемента при пороге 0 из второго элемента. Тогда мы хотя бы сможем посмотреть на график)
#
# А еще разделим количество юзерагентов на **8**, а то 'Score true positive' плохо видно

# %%
s_tp[0] = s_tp[1]
s_lc[0] = s_lc[1]

s_lc = s_lc / 8

# %%
fixed_count = 2

s_t = np.full(len(scores['f0']), fixed_count / 8)

plot(alphas, s_tp, '-b', label='Score true positive');
plot(alphas, s_lc, '-r', label='Score label count');
plot(alphas, s_t, '-g', label='Label count limit');

wanted_score = np.max(scores[scores['f1'] < fixed_count]['f0'])

scatter(alphas[np.argwhere(scores['f0'] == wanted_score)], wanted_score);
xlabel('alpha')

alpha = float(alphas[np.argwhere(scores['f0'] == wanted_score)])

print("Max label average: " + str(fixed_count))
print("Wanted Score: " + str(wanted_score))
print("Alpha: " + str(alpha))
# Out:
# Max label average: 2
# Wanted Score: 0.795161973264
# Alpha: 0.08274774774774774

# %%
fixed_count = 3

s_t = np.full(len(scores['f0']), fixed_count / 8)

plot(alphas, s_tp, '-b', label='Score true positive');
plot(alphas, s_lc, '-r', label='Score label count');
plot(alphas, s_t, '-g', label='Label count limit');

wanted_score = np.max(scores[scores['f1'] < fixed_count]['f0'])

scatter(alphas[np.argwhere(scores['f0'] == wanted_score)], wanted_score);
xlabel('alpha')

alpha = float(alphas[np.argwhere(scores['f0'] == wanted_score)])

print("Max label average: " + str(fixed_count))
print("Wanted Score: " + str(wanted_score))
print("Alpha: " + str(alpha))
# Out:
# Max label average: 3
# Wanted Score: 0.858648014033
# Alpha: 0.04463363363363363

# %%
fixed_count = 4.5

s_t = np.full(len(scores['f0']), fixed_count / 8)

plot(alphas, s_tp, '-b', label='Score true positive');
plot(alphas, s_lc, '-r', label='Score label count');
plot(alphas, s_t, '-g', label='Label count limit');

wanted_score = np.max(scores[scores['f1'] < fixed_count]['f0'])

scatter(alphas[np.argwhere(scores['f0'] == wanted_score)], wanted_score);
xlabel('alpha')

alpha = float(alphas[np.argwhere(scores['f0'] == wanted_score)])

print("Max label average: " + str(fixed_count))
print("Wanted Score: " + str(wanted_score))
print("Alpha: " + str(alpha))
# Out:
# Max label average: 4.5
# Wanted Score: 0.92117722751
# Alpha: 0.02407207207207207

# %%
# %%time
smart_clf = OneVsRestClassifier(LogisticRegression(random_state=42, C=100))
smart_clf.fit(X_train, y_train)
answer = smart_clf.predict(X_test)
# Out:
# CPU times: user 4min 22s, sys: 96 ms, total: 4min 22s
# Wall time: 4min 25s

# %%
def smart_prediction(pred, clf, X_test, y_test, alpha):
    """
    :param clf: Classifyer
    :param X_test: X test sample
    :param y_test: y test sample
    :param alpha: Threshold
    :return: list of list true User Agent names from test sample, list of list Predicted User Agent, list of bool true if at least one predicted User Agent equal true User Agent, list of answer count
    """
    predictions_proba = clf.predict_proba(X_test)

    y_test_names = pd.DataFrame(y_test).apply(
        lambda l: pred.return_prediction_ua(l), axis=1)
    y_predicted = pd.DataFrame(predictions_proba).apply(
        lambda l: pred.return_thresolded_prediction_ua(l, alpha), axis=1)

    compare_answers = []
    answers_count = []
    for i, y_tst in enumerate(y_test_names):
        current_answer = True
        if y_tst not in y_predicted[i]:
            current_answer = False
        compare_answers.append(current_answer)
        answers_count.append(len(y_predicted[i]))

    return y_test_names, y_predicted, compare_answers, answers_count

# %%
y_test_names, y_predicted, compare_answers, answers_count = smart_prediction(pred, smart_clf, X_test, y_test, alpha)

# %%
compare_frame = pd.concat(
    [
        y_test_names,
        y_predicted, 
        pd.DataFrame(compare_answers), 
        pd.DataFrame(answers_count)
    ], keys=['test', 'predicted', 'correctness', 'count'], axis=1, join='inner')

print("Answers Count (Average) = {0}".format(np.average(answers_count)))
smart_accuracy = numpy.sum(compare_answers) / y_test.shape[0]
print("True Positive = {0}".format(smart_accuracy))
compare_frame
# Out:
# Answers Count (Average) = 4.63576677609105
# True Positive = 0.9589741880655214
#                                                     test  \
#                                                        0
# 0      Mozilla/5.0 (Windows NT 6.3; Win64; x64) Apple...
# 1      netEstate NE Crawler (+http://www.website-date...
# 2      Mozilla/5.0 (iPhone; CPU iPhone OS 10_2_1 like...
# 3      Mozilla/5.0 (compatible; MJ12bot/v1.4.7; http:...
# 4      Mozilla/5.0 (compatible; Yahoo! Slurp; http://...
# ...                                                  ...
# 60006  Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.3...
# 60007  Mozilla/5.0 (iPad; CPU OS 9_3_5 like Mac OS X)...
# 60008  Mozilla/5.0 (iPad; CPU OS 9_3_5 like Mac OS X)...
# 60009  Mozilla/5.0 (iPad; CPU OS 10_2_1 like Mac OS X...
# 60010       StackRambler/2.0 (MSIE incompatible; Top100)
#
#                                                predicted correctness count
#                                                        1           0     0
# 0      [Mozilla/5.0 (Windows NT 6.3; Win64; x64) Appl...        True     1
# 1      [Mozilla/5.0 (compatible; Yahoo! Slurp; http:/...        True     5
# 2      [Mozilla/5.0 (compatible; Yahoo! Slurp; http:/...        True    14
# 3      [Mozilla/5.0 (compatible; MJ12bot/v1.4.7; http...        True     1
# 4      [Mozilla/5.0 (compatible; Yahoo! Slurp; http:/...        True    14
# ...                                                  ...         ...   ...
# 60006  [Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537....        True     1
# 60007  [Mozilla/5.0 (iPad; CPU OS 9_3_5 like Mac OS X...        True     1
# 60008  [Mozilla/5.0 (iPad; CPU OS 9_3_5 like Mac OS X...        True     1
# 60009  [Mozilla/5.0 (iPad; CPU OS 10_2_1 like Mac OS ...        True     2
# 60010  [Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537....        True     5
#
# [60011 rows x 4 columns]

# %%
y_test_names, y_predicted, compare_answers, answers_count = smart_prediction(pred, smart_clf, X_test, y_test, 0.02407207207207207)

compare_frame = pd.concat(
    [
        y_test_names,
        y_predicted, 
        pd.DataFrame(compare_answers), 
        pd.DataFrame(answers_count)
    ], keys=['test', 'predicted', 'correctness', 'count'], axis=1, join='inner')

print("Answers Count (Average) = {0}".format(np.average(answers_count)))
smart_accuracy = numpy.sum(compare_answers) / y_test.shape[0]
print("True Positive = {0}".format(smart_accuracy))
compare_frame
# Out:
# Answers Count (Average) = 4.853443535351852
# True Positive = 0.9427271666861076
#                                                     test  \
#                                                        0
# 0      Mozilla/5.0 (Windows NT 6.3; Win64; x64) Apple...
# 1      netEstate NE Crawler (+http://www.website-date...
# 2      Mozilla/5.0 (iPhone; CPU iPhone OS 10_2_1 like...
# 3      Mozilla/5.0 (compatible; MJ12bot/v1.4.7; http:...
# 4      Mozilla/5.0 (compatible; Yahoo! Slurp; http://...
# ...                                                  ...
# 60006  Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.3...
# 60007  Mozilla/5.0 (iPad; CPU OS 9_3_5 like Mac OS X)...
# 60008  Mozilla/5.0 (iPad; CPU OS 9_3_5 like Mac OS X)...
# 60009  Mozilla/5.0 (iPad; CPU OS 10_2_1 like Mac OS X...
# 60010       StackRambler/2.0 (MSIE incompatible; Top100)
#
#                                                predicted correctness count
#                                                        1           0     0
# 0      [Mozilla/5.0 (Windows NT 6.3; Win64; x64) Appl...        True     1
# 1      [Mozilla/5.0 (compatible; Yahoo! Slurp; http:/...        True     5
# 2      [Mozilla/5.0 (compatible; Yahoo! Slurp; http:/...        True    14
# 3      [Mozilla/5.0 (compatible; MJ12bot/v1.4.7; http...        True     1
# 4      [Mozilla/5.0 (compatible; Yahoo! Slurp; http:/...        True    14
# ...                                                  ...         ...   ...
# 60006  [Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537....        True     1
# 60007  [Mozilla/5.0 (iPad; CPU OS 9_3_5 like Mac OS X...        True     1
# 60008  [Mozilla/5.0 (iPad; CPU OS 9_3_5 like Mac OS X...        True     1
# 60009  [Mozilla/5.0 (iPad; CPU OS 10_2_1 like Mac OS ...        True     2
# 60010  [Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537....        True     5
#
# [60011 rows x 4 columns]

# %% [markdown]
# ### До меня дошло что количество лейблов это tp + fp
#
# Знвчит можно считать precision и затачивать на него кстати.
#
# Ведь
#
# $$
# precision = \frac{tp}{tp+fp}\
# $$

# %%
from sklearn.metrics import precision_score

def p_score(alpha, y, y_hat_dummy):
    return precision_score(y, (y_hat_dummy > alpha).astype('int'), average='samples')

# %%
p_s = [p_score(alpha, y, y_hat_dummy) for alpha in alphas]

# %%
fixed_count = 4.5

s_t = np.full(len(scores['f0']), fixed_count / 8)

plot(alphas, s_tp, '-b', label='Score true positive');
plot(alphas, s_lc, '-r', label='Score label count');
plot(alphas, p_s, '-g', label='Precision');

wanted_score = np.max(scores[scores['f1'] < fixed_count]['f0'])

scatter(alphas[np.argwhere(scores['f0'] == wanted_score)], wanted_score);
scatter(alphas[np.argmax(p_s)], np.max(p_s), color='green');
xlabel('alpha')

alpha = float(alphas[np.argwhere(scores['f0'] == wanted_score)])

print("Max label average: " + str(fixed_count))
print("Wanted Score: " + str(wanted_score))
print("Alpha: " + str(alpha))
print("Max Precision: " + str(np.max(p_s)))
print("Max Alpha by Precision: " + str(alphas[np.argmax(p_s)]))
# Out:
# Max label average: 4.5
# Wanted Score: 0.92117722751
# Alpha: 0.02407207207207207
# Max Precision: 0.623126442344
# Max Alpha by Precision: 0.337009009009

# %% [markdown]
# ### Подберем важные values признаки

# %%
' '.join(important_keys)
# Out:
# 'Accept Accept-Charset Accept-Encoding Cache-Control Connection Content-Length Content-Type Device-Stock-Ua Dnt From Keep-Alive Pragma Proxy-Connection Range Save-Data Scheme Surrogate-Capability Te Upgrade-Insecure-Requests X-Compress X-Forwarded-Proto X-Moz X-Operamini-Features X-Operamini-Phone X-Operamini-Phone-Ua X-Turbo-Compression X-Yandex-Turbo'

# %%
real_keys = ['Accept', 'Accept-Encoding', 'Cache-Control']

values_data_top_100 = []

for row_index in tqdm(range(len(trimmed_values_data))):
    tmp_row = {}
    for key in trimmed_values_data[row_index].keys():
        if key in real_keys:
            tmp_row[key] = trimmed_values_data[row_index][key]
    if row_index in main_top_100.index:
        values_data_top_100.append(tmp_row)

values_vectorizer = sklearn.feature_extraction.DictVectorizer(sparse=True, dtype=float)
sparse_dummy_values = orders_vectorizer.fit_transform(values_data_top_100).astype(np.int8)

print('Headers: ' + str(' '.join(important_keys)))
print('sparse_dummy_values.shape: ' + str(sparse_dummy_values.shape))
# Out:
# 100%|██████████| 289269/289269 [00:00<00:00, 354679.96it/s]
# Headers: Accept Accept-Encoding Cache-Control
# sparse_dummy_values.shape: (181851, 136)

# %%
# %%time

full_sparce_dummy = hstack((sparse_dummy, sparse_dummy_values))

lb = preprocessing.LabelBinarizer()
lb.fit(top_ua)
y = lb.transform(main_top_100.User_Agent)

X_train, X_test, y_train, y_test = train_test_split(full_sparce_dummy, y, test_size=0.33, random_state=42)

smart_clf = OneVsRestClassifier(LogisticRegression(random_state=42, C=100))
smart_clf.fit(X_train, y_train)
answer = smart_clf.predict(X_test)
# Out:
# CPU times: user 4min 56s, sys: 184 ms, total: 4min 56s
# Wall time: 5min 2s

# %%
y_test_names, y_predicted, compare_answers, answers_count = smart_prediction(pred, smart_clf, X_test, y_test, 0.02407207207207207)

compare_frame = pd.concat(
    [
        y_test_names,
        y_predicted, 
        pd.DataFrame(compare_answers), 
        pd.DataFrame(answers_count)
    ], keys=['test', 'predicted', 'correctness', 'count'], axis=1, join='inner')

print('Headers: ' + str(' '.join(important_keys)))
print('sparse_dummy_values.shape: ' + str(sparse_dummy_values.shape))
print("Answers Count (Average) = {0}".format(np.average(answers_count)))
smart_accuracy = numpy.sum(compare_answers) / y_test.shape[0]
print("True Positive = {0}".format(smart_accuracy))
compare_frame
# Out:
# Headers: Accept Accept-Charset Accept-Encoding Cache-Control Connection Content-Length Content-Type Device-Stock-Ua Dnt From Keep-Alive Pragma Proxy-Connection Range Save-Data Scheme Surrogate-Capability Te Upgrade-Insecure-Requests X-Compress X-Forwarded-Proto X-Moz X-Operamini-Features X-Operamini-Phone X-Operamini-Phone-Ua X-Turbo-Compression X-Yandex-Turbo
# sparse_dummy_values.shape: (181851, 1374)
# Answers Count (Average) = 4.546316508640083
# True Positive = 0.9588075519488094
#                                                     test  \
#                                                        0
# 0      Mozilla/5.0 (Windows NT 6.3; Win64; x64) Apple...
# 1      netEstate NE Crawler (+http://www.website-date...
# 2      Mozilla/5.0 (iPhone; CPU iPhone OS 10_2_1 like...
# 3      Mozilla/5.0 (compatible; MJ12bot/v1.4.7; http:...
# 4      Mozilla/5.0 (compatible; Yahoo! Slurp; http://...
# ...                                                  ...
# 60006  Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.3...
# 60007  Mozilla/5.0 (iPad; CPU OS 9_3_5 like Mac OS X)...
# 60008  Mozilla/5.0 (iPad; CPU OS 9_3_5 like Mac OS X)...
# 60009  Mozilla/5.0 (iPad; CPU OS 10_2_1 like Mac OS X...
# 60010       StackRambler/2.0 (MSIE incompatible; Top100)
#
#                                                predicted correctness count
#                                                        1           0     0
# 0      [Mozilla/5.0 (Windows NT 6.3; Win64; x64) Appl...        True     1
# 1      [Mozilla/5.0 (compatible; Yahoo! Slurp; http:/...        True     5
# 2      [Mozilla/5.0 (compatible; Yahoo! Slurp; http:/...        True    14
# 3      [Mozilla/5.0 (compatible; MJ12bot/v1.4.7; http...        True     1
# 4      [Mozilla/5.0 (compatible; Yahoo! Slurp; http:/...        True    14
# ...                                                  ...         ...   ...
# 60006  [Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537....        True     1
# 60007  [Mozilla/5.0 (iPad; CPU OS 9_3_5 like Mac OS X...        True     1
# 60008  [Mozilla/5.0 (iPad; CPU OS 9_3_5 like Mac OS X...        True     1
# 60009  [Mozilla/5.0 (iPad; CPU OS 10_2_1 like Mac OS ...        True     2
# 60010  [Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537....        True     5
#
# [60011 rows x 4 columns]

# %%
#real_keys = ['Accept', 'Accept-Charset', 'Accept-Encoding']
real_keys = []
v_shapes = []
v_averages = []
v_tp = []

for i in tqdm(range(len(important_keys))):
    real_keys.append(important_keys[i])

    values_data_top_100 = []

    for row_index in range(len(trimmed_values_data)):
        tmp_row = {}
        for key in trimmed_values_data[row_index].keys():
            if key in real_keys:
                tmp_row[key] = trimmed_values_data[row_index][key]
        if row_index in main_top_100.index:
            values_data_top_100.append(tmp_row)

    values_vectorizer = sklearn.feature_extraction.DictVectorizer(sparse=True, dtype=float)
    sparse_dummy_values = orders_vectorizer.fit_transform(values_data_top_100).astype(np.int8)
    
    full_sparce_dummy = hstack((sparse_dummy, sparse_dummy_values))

    lb = preprocessing.LabelBinarizer()
    lb.fit(top_ua)
    y = lb.transform(main_top_100.User_Agent)

    X_train, X_test, y_train, y_test = train_test_split(full_sparce_dummy, y, test_size=0.33, random_state=42)

    smart_clf = OneVsRestClassifier(LogisticRegression(random_state=42, C=100))
    smart_clf.fit(X_train, y_train)
    answer = smart_clf.predict(X_test)
    
    y_test_names, y_predicted, compare_answers, answers_count = smart_prediction(pred, smart_clf, X_test, y_test, 0.02407207207207207)
    
    v_shapes.append(sparse_dummy_values.shape[1])
    v_averages.append(np.average(answers_count))
    v_tp.append(np.sum(compare_answers) / y_test.shape[0])
# Out:
#   0%|          | 0/27 [00:00<?, ?it/s]
#   4%|▎         | 1/27 [04:34<1:59:00, 274.65s/it]
# 48
# 4.8532269084
# 0.942727166686
#   7%|▋         | 2/27 [08:57<1:52:59, 271.16s/it]
# 70
# 4.85344353535
# 0.942727166686
#  11%|█         | 3/27 [13:54<1:51:34, 278.92s/it]
# 93
# 4.58797553782
# 0.959824032261
#  15%|█▍        | 4/27 [18:39<1:47:38, 280.82s/it]
# 158
# 4.58707570279
# 0.959740714202
#  19%|█▊        | 5/27 [23:21<1:43:01, 280.99s/it]
# 164
# 4.58335971739
# 0.959724050591
#  22%|██▏       | 6/27 [28:04<1:38:33, 281.60s/it]
# 230
# 4.5836596624
# 0.959740714202
#  26%|██▌       | 7/27 [33:13<1:36:35, 289.78s/it]
# 233
# 4.58357634434
# 0.959757377814
#  30%|██▉       | 8/27 [37:56<1:31:11, 287.98s/it]
# 233
# 4.58357634434
# 0.959757377814
#  33%|███▎      | 9/27 [42:59<1:27:39, 292.21s/it]
# 234
# 4.5835263535
# 0.959740714202
#  37%|███▋      | 10/27 [47:51<1:22:48, 292.25s/it]
# 238
# 4.58354301711
# 0.959740714202
#  41%|████      | 11/27 [52:40<1:17:41, 291.33s/it]
# 240
# 4.5835263535
# 0.959740714202
#  44%|████▍     | 12/27 [57:46<1:13:54, 295.63s/it]
# 241
# 4.58340970822
# 0.959740714202
#  48%|████▊     | 13/27 [1:03:03<1:10:28, 302.01s/it]
# 244
# 4.5835263535
# 0.959807368649
#  52%|█████▏    | 14/27 [1:08:17<1:06:14, 305.70s/it]
# 245
# 4.58360967156
# 0.959807368649
#  56%|█████▌    | 15/27 [1:13:13<1:00:35, 302.92s/it]
# 246
# 4.58305977238
# 0.959774041426
#  59%|█████▉    | 16/27 [1:17:58<54:32, 297.46s/it]
# 247
# 4.58302644515
# 0.959774041426
#  63%|██████▎   | 17/27 [1:22:55<49:33, 297.37s/it]
# 308
# 4.57842728833
# 0.959507423639
#  67%|██████▋   | 18/27 [1:27:53<44:38, 297.58s/it]
# 309
# 4.57832730666
# 0.959490760027
#  70%|███████   | 19/27 [1:32:48<39:33, 296.70s/it]
# 310
# 4.57427804902
# 0.959790705037
#  74%|███████▍  | 20/27 [1:38:04<35:17, 302.47s/it]
# 314
# 4.57304494176
# 0.959740714202
#  78%|███████▊  | 21/27 [1:43:32<31:01, 310.23s/it]
# 315
# 4.57314492343
# 0.959740714202
#  81%|████████▏ | 22/27 [1:48:58<26:14, 314.94s/it]
# 316
# 4.5730949326
# 0.959740714202
#  85%|████████▌ | 23/27 [1:53:47<20:28, 307.16s/it]
# 316
# 4.5730949326
# 0.959740714202
#  89%|████████▉ | 24/27 [1:58:33<15:02, 300.79s/it]
# 316
# 4.5730949326
# 0.959740714202
#  93%|█████████▎| 25/27 [2:03:21<09:53, 296.83s/it]
# 316
# 4.5730949326
# 0.959740714202
#  96%|█████████▋| 26/27 [2:08:16<04:56, 296.41s/it]
# 317
# 4.57306160537
# 0.959740714202
# 100%|██████████| 27/27 [2:14:19<00:00, 316.28s/it]
# 318
# 4.57317825065
# 0.959740714202

# %%
plot(range(len(important_keys)), v_tp, '-g', label='True Positive');

# %%
plot(range(2, len(important_keys)), v_tp[2:], '-g', label='True Positive');
scatter(np.argmax(v_tp), np.max(v_tp), color='red');
scatter(np.argmax(v_tp[2:]) + 2, np.max(v_tp[2:]));
scatter(np.argmax(v_tp[3:]) + 3, np.max(v_tp[3:]), color='red');
print('Red dot:')
print(np.max(v_tp[3:]))
print(np.argmax(v_tp[3:]) + 3)
print('Blue dot:')
print(np.max(v_tp[2:]))
# Out:
# Red dot:
# 0.959807368649
# 12
# Blue dot:
# 0.959824032261

# %%
plot(range(len(important_keys)), np.array(v_averages), '-r', label='Answers Count (Average)');

# %%
plot(range(len(important_keys)), np.array(v_shapes), '-b', label='Values features shape');
